# %%
import pandas as pd
from pathlib import Path
from config import geoapify_key
import requests
import json
from pprint import pprint
import re

# %%
# files  = [
#     "listings_toronto_type1_pages001-162_2024-01-30.csv",
#     "listings_toronto_type2_pages001-016_2024-01-30.csv",
#     "listings_toronto_type3_pages001-015_2024-01-30.csv",
#     "listings_toronto_type5_pages001-050_2024-01-30.csv"
# ]

files = ["listings_with_locations.csv"]

li = []

for file in files:
    file_path = Path("data/" + file)
    partial_df = pd.read_csv(file_path, index_col="mls_id", header=0)
    li.append(partial_df)

listings_df = pd.concat(li, axis=0)

listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude
# mls_id
# E8018446  43.687469 -79.301861
# C7266728  43.650343 -79.387806
# W7239426  43.622946 -79.481658
# E8030950  43.658361 -79.351159
# E8030860  43.665267 -79.341034

# %%
# Set the search parameters
target_city = "Toronto, Canada"

# Build URL using the geocode endpoint
geo_url = f"https://api.geoapify.com/v1/geocode/search?city=Toronto&type=city&format=json&apiKey={geoapify_key}"
geo_response = requests.get(geo_url).json()
#pprint(geo_response)
toronto_place_id = geo_response['results'][0]['place_id']
toronto_place_id
# Out:
# '512c13d96292d853c0596a04d149a5d34540f00101f90173f2040000000000c00208'

# %%
if 'latitude' not in listings_df.columns:
    listings_df['latitude'] = ""
if 'longitude' not in listings_df.columns:
    listings_df['longitude'] = ""
failed_addresses = []
address_count = 0

for i, row in listings_df.iterrows():
    address_count += 1
    address = listings_df.loc[i, 'address']
    original_address = address

    if pd.isnull(listings_df.loc[i, 'latitude']) or listings_df.loc[i, 'latitude']=="":
    
        #Clean up Address
        address = address.replace("#", "")
        address = address.replace("/", "")
        address = address.replace("-", "")
        address = address.rstrip("0123456789 ")
        address = address.removesuffix(' Ph')
        address = address.removesuffix(' Tp')
        address = address.removesuffix(' Lph')
        address = address.removesuffix(' Sph')
        address = address.removesuffix(' Uph')
        address = address.removesuffix(' N/A')
        address = address.removesuffix(' NA')
        address = address.removesuffix(' Nt')
        address = address.rstrip("0123456789 ")
        address = address.replace(" Don Way", " DonWay")
        address = address.replace("Queensway Way", "Queensway")
        address = address.replace("Gfwy", "Golfway")
        address = address.replace("Glwy", "Glenway")
        if address[-3:] == " Sq":
            address = address[:-3] + " Square"
        if address[-3:] == " Dr":
            address = address[:-3] + " Drive"
        if address[-2:] == " W":
            address = address[:-2] + " West"
        if address[-2:] == " E":
            address = address[:-2] + " East"
        
        pattern_1 = re.compile(r'\s\d+[A-Za-z]$')
        match = pattern_1.search(address)
        if match:
            address = address.replace(match.group(0), '')
        
        pattern_2 = re.compile(r'\s\[A-Za-z]$')
        match2 = pattern_2.search(address)
        if match2:
            address = address.replace(match2.group(0), '')
        
        address_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={address}&filter=place:{toronto_place_id}&format=json&apiKey={geoapify_key}"
        address_response = requests.get(address_url).json()
        try:
            listings_df.at[i, 'latitude'] = address_response['results'][0]['lat']
            listings_df.at[i, 'longitude'] = address_response['results'][0]['lon']
            print(f'API call {address_count} successful for {address}')
        except IndexError:
            print(f'API call {address_count} failed for {address}')
            #If first attempt fails remove the house number and check for the street address
            address = address.lstrip("0123456789 ")
            address_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={address}&filter=place:{toronto_place_id}&format=json&apiKey={geoapify_key}"
            address_response = requests.get(address_url).json()
            try:
                listings_df.at[i, 'latitude'] = address_response['results'][0]['lat']
                listings_df.at[i, 'longitude'] = address_response['results'][0]['lon']
                print(f'API call {address_count} successful for {address}')
            except:
                #append the failed addresses to a list to keep track of them
                failed_addresses.append(original_address)
                print(f'API call {address_count} failed for {address}')
# Out:
# API call 69 failed for 33 Frederick Todd Way
# API call 69 failed for Frederick Todd Way
# API call 119 failed for 33 Frederick Todd Way
# API call 119 failed for Frederick Todd Way
# API call 211 failed for 52 Forest Manor Rd P
# API call 211 failed for Forest Manor Rd P
# API call 419 failed for 55 Merchants Wharf St
# API call 419 failed for Merchants Wharf St
# API call 489 failed for 33 Frederick Todd Way
# API call 489 failed for Frederick Todd Way
# API call 726 failed for 27 Rean Ave
# API call 726 failed for Rean Ave
# API call 804 failed for 30 Tretti Way
# API call 804 failed for Tretti Way
# API call 816 failed for 36 Lisgar St Lph06E
# API call 816 failed for Lisgar St Lph06E
# API call 846 failed for 120 Parliment St
# API call 846 failed for Parliment St
# API call 857 failed for 60 Heintzman Pl
# API call 857 failed for Heintzman Pl
# API call 860 failed for 225 Sherway Garderns Rd
# API call 860 failed for Sherway Garderns Rd
# API call 877 failed for 30 Shorebreeze Drive
# API call 877 failed for Shorebreeze Drive
# API call 922 failed for 725 Donmills Rd
# API call 922 failed for Donmills Rd
# API call 962 failed for 8 The Esplanade St
# API call 962 failed for The Esplanade St
# API call 1134 failed for 60 Pavane Line
# API call 1134 failed for Pavane Line
# API call 1217 failed for 65 Bremmer Blvd
# API call 1217 failed for Bremmer Blvd
# API call 1295 failed for 30 Tretti Way
# API call 1295 failed for Tretti Way
# API call 1339 failed for 455 Front St S
# API call 1339 failed for Front St S
# API call 1358 failed for 73 Richmond St L
# API call 1358 failed for Richmond St L
# API call 1397 failed for 50 Lotherton Pkwy
# API call 1397 failed for Lotherton Pkwy
# API call 1429 failed for 33 Frederick Todd Way
# API call 1429 failed for Frederick Todd Way
# API call 1435 failed for 33 Frederick Todd Way
# API call 1435 failed for Frederick Todd Way
# API call 1471 failed for 5 San Romano Way
# API call 1471 failed for San Romano Way
# API call 1505 failed for 8 The Esplanade Drive
# API call 1505 failed for The Esplanade Drive
# API call 1518 failed for 2500 Bridlestowne Circ
# API call 1518 failed for Bridlestowne Circ
# API call 1607 failed for 296 Mill Rd G
# API call 1607 failed for Mill Rd G
# API call 1658 failed for 455 Front St S
# API call 1658 failed for Front St S
# API call 1689 successful for 20 Bruyeres Mews
# API call 1692 failed for 60 Pavane Linkway Way
# API call 1692 failed for Pavane Linkway Way
# API call 1722 successful for 1 The Esplanade
# API call 1860 failed for 10 Deerlick Drive
# API call 1860 failed for Deerlick Drive
# API call 2022 failed for 8 The Esplanade St
# API call 2022 failed for The Esplanade St
# API call 2150 failed for 20 Edgecliffe Golfway
# API call 2150 failed for Edgecliffe Golfway
# API call 2169 failed for 55 Ann O'reily Rd
# API call 2169 failed for Ann O'reily Rd
# API call 2192 failed for 30 Tretti Way
# API call 2192 failed for Tretti Way
# API call 2216 successful for 8 The Esplanade
# API call 2217 failed for 30 Tretti Way
# API call 2217 failed for Tretti Way
# API call 2279 failed for 125 Village Green Square Square
# API call 2279 failed for Village Green Square Square
# API call 2309 successful for 859 The Queensway
# API call 2313 successful for 85 The Donway
# API call 2418 failed for 407 Walmer Rd 701Ph
# API call 2418 failed for Walmer Rd 701Ph
# API call 2445 successful for 859 The Queensway
# API call 2495 successful for 1 The Esplanade
# API call 2498 failed for 539 Jarvis St Gt
# API call 2498 failed for Jarvis St Gt
# API call 2509 failed for 40 Sylvan Valley Way
# API call 2509 failed for Sylvan Valley Way
# API call 2545 failed for 2433 Duffrin St
# API call 2545 failed for Duffrin St
# API call 2586 successful for 39 Queens Quay
# API call 2592 successful for 10 Northtown
# API call 2602 failed for 90 Broadview Ave Lw
# API call 2602 failed for Broadview Ave Lw
# API call 2613 failed for 30 Tretti Way
# API call 2613 failed for Tretti Way
# API call 2615 failed for 38 Forest Manner Rd
# API call 2615 failed for Forest Manner Rd
# API call 2616 failed for 10 Capreol Crt Parking
# API call 2616 failed for Capreol Crt Parking
# API call 2667 successful for 103 The Queensway
# API call 2708 successful for 105 The Queensway
# API call 2711 successful for 859 The Queensway
# API call 2769 failed for 2 Clairtrell Rd Rg
# API call 2769 failed for Clairtrell Rd Rg
# API call 2787 successful for 1 The Esplanade
# API call 2819 successful for 103 The Queensway
# API call 2842 failed for 455 Front St S
# API call 2842 failed for Front St S
# API call 2862 failed for 99 Broadway Ave Parking
# API call 2862 failed for Broadway Ave Parking
# API call 2915 failed for 5 San Romano Way
# API call 2915 failed for San Romano Way
# API call 2947 failed for 8 The Esplanade Ave
# API call 2947 failed for The Esplanade Ave
# API call 3027 failed for 455 Front St N
# API call 3027 failed for Front St N
# API call 3038 successful for 859 The Queensway
# API call 3076 failed for 60 Pavane Linkway Lane
# API call 3076 failed for Pavane Linkway Lane
# API call 3079 successful for 60 Pavane Linkway
# API call 3114 successful for 8 The Esplanade
# API call 3136 failed for 90 Gleneverest Rd
# API call 3136 failed for Gleneverest Rd
# API call 3141 failed for 10 Gibbs St
# API call 3141 failed for Gibbs St
# API call 3157 failed for 33 Frederick Todd Way
# API call 3157 failed for Frederick Todd Way
# API call 3223 failed for 2300 St. Clair Ave. West Ally
# API call 3223 failed for St. Clair Ave. West Ally
# API call 3352 failed for 6 Akil Thomas Gdns
# API call 3352 failed for Akil Thomas Gdns
# API call 3490 failed for 16 Kirtling Pl
# API call 3490 failed for Kirtling Pl
# API call 3491 failed for 16 Kirtling Pl
# API call 3491 failed for Kirtling Pl
# API call 3495 failed for 72 Hooyo Terr
# API call 3495 failed for Hooyo Terr
# API call 3496 failed for 62 Danielle Moore Circ
# API call 3496 failed for Danielle Moore Circ
# API call 3541 failed for 89 Rock Fern Way
# API call 3541 failed for Rock Fern Way
# API call 3579 failed for 111 Brickworks Lane Bw
# API call 3579 failed for Brickworks Lane Bw
# API call 3590 failed for 38 Kenaston Gdns Gv
# API call 3590 failed for Kenaston Gdns Gv
# API call 3632 failed for 10 Lloyd Janes Lane
# API call 3632 failed for Lloyd Janes Lane
# API call 3646 failed for 30 William Jackson Way Th
# API call 3646 failed for William Jackson Way Th
# API call 3658 failed for 184 Woody Vine Way
# API call 3658 failed for Woody Vine Way
# API call 3659 failed for 39 Candle Lite Way
# API call 3659 failed for Candle Lite Way
# API call 3666 failed for 21 Livonia Pl
# API call 3666 failed for Livonia Pl
# API call 3692 failed for 5 William Jackson Way
# API call 3692 failed for William Jackson Way
# API call 3697 failed for 108 Fort York Blvd G
# API call 3697 failed for Fort York Blvd G
# API call 3710 failed for 5 Dutch Myrtle Way
# API call 3710 failed for Dutch Myrtle Way
# API call 3712 successful for 93 The Queensway
# API call 3732 successful for 104 Farm Greenway
# API call 3738 failed for 1248 Avenue Rd C
# API call 3738 failed for Avenue Rd C
# API call 3740 failed for 19 Maroon Mill Way
# API call 3740 failed for Maroon Mill Way
# API call 3754 failed for 225 Brimingham St
# API call 3754 failed for Brimingham St
# API call 3755 failed for 30 William Jackson Way
# API call 3755 failed for William Jackson Way
# API call 3762 failed for 123 Brickworks Lane Bl
# API call 3762 failed for Brickworks Lane Bl
# API call 3773 failed for 96 Fort York Blvd G
# API call 3773 failed for Fort York Blvd G
# API call 3802 failed for 36 Wild Ginger Way
# API call 3802 failed for Wild Ginger Way
# API call 3953 failed for 830 Scarborough Golfclub Rd
# API call 3953 failed for Scarborough Golfclub Rd
# API call 4076 failed for 88 Saint George St
# API call 4076 failed for Saint George St
# API call 4124 failed for 135 Crescent Rd + Coach
# API call 4124 failed for Crescent Rd + Coach
# API call 4127 failed for 135 Crescent Rd Coach H
# API call 4127 failed for Crescent Rd Coach H
# API call 4229 failed for 24 TwentyThird St
# API call 4229 failed for TwentyThird St
# API call 4442 failed for 21 Freemon Redmon Circ
# API call 4442 failed for Freemon Redmon Circ
# API call 4483 failed for 41 Nielson Ave
# API call 4483 failed for Nielson Ave
# API call 4652 failed for 71 Danielle Moore Circ
# API call 4652 failed for Danielle Moore Circ
# API call 4659 successful for 238 South Kingsway
# API call 4727 successful for 821 The Queensway

# %%
with open("data/failed_addresses.txt", "w") as output:
    for entry in failed_addresses:
        output.write(str(entry))
        output.write('\n')

# %%
listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude
# mls_id
# E8018446  43.687469 -79.301861
# C7266728  43.650343 -79.387806
# W7239426  43.622946 -79.481658
# E8030950  43.658361 -79.351159
# E8030860  43.665267 -79.341034

# %%
listings_df.to_csv('data/listings_with_locations.csv')

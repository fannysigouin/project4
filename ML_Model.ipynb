# %%
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
file = "listings_with_locations.csv"

file_path = Path("data/" + file)
listings_df = pd.read_csv(file_path, index_col="mls_id", header=0)


listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude
# mls_id
# E8018446  43.687469 -79.301861
# C7266728  43.650343 -79.387806
# W7239426  43.622946 -79.481658
# E8030950  43.658361 -79.351159
# E8030860  43.665267 -79.341034

# %%
listings_df = listings_df[(listings_df['baths'] != 0)]
listings_df = listings_df[(listings_df['baths'] <= 5)]

listings_df = listings_df.dropna(subset=["latitude"])

# %%
# Function to remove outliers (IQR)
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers for each property type

for i in range(0,4):
    cleaned_df = pd.DataFrame()

    for property_type in listings_df['property_type'].unique():
        subset_df = listings_df[listings_df['property_type'] == property_type]
        cleaned_subset = remove_outliers(subset_df, 'price')
        cleaned_df = pd.concat([cleaned_df, cleaned_subset])

    listings_df = cleaned_df


for i in range(0,1):
    cleaned_df = pd.DataFrame()

    for property_type in listings_df['property_type'].unique():
        subset_df = listings_df[listings_df['property_type'] == property_type]
        cleaned_subset = remove_outliers(subset_df, 'beds')
        cleaned_df = pd.concat([cleaned_df, cleaned_subset])

    listings_df = cleaned_df


for i in range(0,1):
    cleaned_df = pd.DataFrame()

    for property_type in listings_df['property_type'].unique():
        subset_df = listings_df[listings_df['property_type'] == property_type]
        cleaned_subset = remove_outliers(subset_df, 'dens')
        cleaned_df = pd.concat([cleaned_df, cleaned_subset])

    listings_df = cleaned_df

# %%
listings_df.count()
# Out:
# url              3853
# address          3853
# price            3853
# baths            3853
# beds             3853
# dens             3853
# street           3853
# neighbourhood    3853
# city             3853
# property_type    3853
# date_scraped     3853
# latitude         3853
# longitude        3853
# dtype: int64

# %%
listings_df['rel_latitude'] = listings_df['latitude'] - 43
listings_df['rel_longitude'] = listings_df['longitude'] + 79

listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude  rel_latitude  rel_longitude
# mls_id
# E8018446  43.687469 -79.301861      0.687469      -0.301861
# C7266728  43.650343 -79.387806      0.650343      -0.387806
# W7239426  43.622946 -79.481658      0.622946      -0.481658
# E8030950  43.658361 -79.351159      0.658361      -0.351159
# E8030860  43.665267 -79.341034      0.665267      -0.341034

# %%
# #Choosing 30 as a cutoff value
# neighbourhoods_to_replace = []
# for value, count in listings_df['neighbourhood'].value_counts().items():
#   if count < 30:
#     neighbourhoods_to_replace.append(value)

# # Replace in dataframe
# for app in neighbourhoods_to_replace:
#     listings_df['neighbourhood'] = listings_df['neighbourhood'].replace(app,"Other")

# # Check to make sure binning was successful
# #listings_df['neighbourhood'].value_counts()

# %%
listings_df.nunique()
# Out:
# url              3853
# address          3848
# price            1150
# baths               5
# beds                6
# dens                6
# street           1213
# neighbourhood     143
# city                1
# property_type       4
# date_scraped        1
# latitude         2198
# longitude        2199
# rel_latitude     2198
# rel_longitude    2199
# dtype: int64

# %%
cat_columns = ["neighbourhood", "property_type"]
num_columns = ["baths", "beds", "dens", "rel_latitude", "rel_longitude"]
y = listings_df["price"]

# %%
listings_df_prepared = pd.get_dummies(listings_df[cat_columns], dtype=int)
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt North  \
# mls_id
# E8018446                              0
# C7266728                              0
# W7239426                              0
# E8030950                              0
# E8030860                              0
#
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# E8018446                                           0                        0
# C7266728                                           0                        0
# W7239426                                           0                        0
# E8030950                                           0                        0
# E8030860                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# E8018446                    0                                0
# C7266728                    0                                0
# W7239426                    0                                0
# E8030950                    0                                0
# E8030860                    0                                0
#
#           neighbourhood_Bathurst Manor  neighbourhood_Bay Street Corridor  \
# mls_id
# E8018446                             0                                  0
# C7266728                             0                                  0
# W7239426                             0                                  0
# E8030950                             0                                  0
# E8030860                             0                                  0
#
#           neighbourhood_Bayview Village  neighbourhood_Bayview Woods-Steeles  \
# mls_id
# E8018446                              0                                    0
# C7266728                              0                                    0
# W7239426                              0                                    0
# E8030950                              0                                    0
# E8030860                              0                                    0
#
#           neighbourhood_Bedford Park-Nortown  ...  \
# mls_id                                        ...
# E8018446                                   0  ...
# C7266728                                   0  ...
# W7239426                                   0  ...
# E8030950                                   0  ...
# E8030860                                   0  ...
#
#           neighbourhood_Woodbine-Lumsden  neighbourhood_Wychwood  \
# mls_id
# E8018446                               0                       0
# C7266728                               0                       0
# W7239426                               0                       0
# E8030950                               0                       0
# E8030860                               0                       0
#
#           neighbourhood_Yonge-Eglinton  neighbourhood_Yonge-St. Clair  \
# mls_id
# E8018446                             0                              0
# C7266728                             0                              0
# W7239426                             0                              0
# E8030950                             0                              0
# E8030860                             0                              0
#
#           neighbourhood_York University Heights  \
# mls_id
# E8018446                                      0
# C7266728                                      0
# W7239426                                      0
# E8030950                                      0
# E8030860                                      0
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# E8018446                                 0                              1
# C7266728                                 0                              1
# W7239426                                 0                              1
# E8030950                                 0                              1
# E8030860                                 0                              1
#
#           property_type_condo_townhome  property_type_detached_home  \
# mls_id
# E8018446                             0                            0
# C7266728                             0                            0
# W7239426                             0                            0
# E8030950                             0                            0
# E8030860                             0                            0
#
#           property_type_freehold _townhome
# mls_id
# E8018446                                 0
# C7266728                                 0
# W7239426                                 0
# E8030950                                 0
# E8030860                                 0
#
# [5 rows x 147 columns]

# %%
listings_df_prepared[num_columns] = listings_df[num_columns]
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt North  \
# mls_id
# E8018446                              0
# C7266728                              0
# W7239426                              0
# E8030950                              0
# E8030860                              0
#
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# E8018446                                           0                        0
# C7266728                                           0                        0
# W7239426                                           0                        0
# E8030950                                           0                        0
# E8030860                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# E8018446                    0                                0
# C7266728                    0                                0
# W7239426                    0                                0
# E8030950                    0                                0
# E8030860                    0                                0
#
#           neighbourhood_Bathurst Manor  neighbourhood_Bay Street Corridor  \
# mls_id
# E8018446                             0                                  0
# C7266728                             0                                  0
# W7239426                             0                                  0
# E8030950                             0                                  0
# E8030860                             0                                  0
#
#           neighbourhood_Bayview Village  neighbourhood_Bayview Woods-Steeles  \
# mls_id
# E8018446                              0                                    0
# C7266728                              0                                    0
# W7239426                              0                                    0
# E8030950                              0                                    0
# E8030860                              0                                    0
#
#           neighbourhood_Bedford Park-Nortown  ...  \
# mls_id                                        ...
# E8018446                                   0  ...
# C7266728                                   0  ...
# W7239426                                   0  ...
# E8030950                                   0  ...
# E8030860                                   0  ...
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# E8018446                                 0                              1
# C7266728                                 0                              1
# W7239426                                 0                              1
# E8030950                                 0                              1
# E8030860                                 0                              1
#
#           property_type_condo_townhome  property_type_detached_home  \
# mls_id
# E8018446                             0                            0
# C7266728                             0                            0
# W7239426                             0                            0
# E8030950                             0                            0
# E8030860                             0                            0
#
#           property_type_freehold _townhome  baths  beds  dens  rel_latitude  \
# mls_id
# E8018446                                 0      1     1     1      0.687469
# C7266728                                 0      1     1     0      0.650343
# W7239426                                 0      1     1     1      0.622946
# E8030950                                 0      2     2     0      0.658361
# E8030860                                 0      1     1     0      0.665267
#
#           rel_longitude
# mls_id
# E8018446      -0.301861
# C7266728      -0.387806
# W7239426      -0.481658
# E8030950      -0.351159
# E8030860      -0.341034
#
# [5 rows x 152 columns]

# %%
X = listings_df_prepared

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
rf_model = RandomForestClassifier(n_estimators=500, random_state=1)

rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions_train = rf_model.predict(X_train_scaled)

# %%
predictions_test = rf_model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
rf_mse_train = mean_squared_error(y_train, predictions_train)
rf_mae_train = mean_absolute_error(y_train, predictions_train)

rf_mse_test = mean_squared_error(y_test, predictions_test)
rf_mae_test = mean_absolute_error(y_test, predictions_test)

# %%
from math import sqrt

# %%
print("Random Forest Train mse = ",rf_mse_train," & mae = ",rf_mae_train," & rmse = ", sqrt(rf_mse_train))
# Out:
# Random Forest Train mse =  1303224237.9103496  & mae =  9896.183108341987  & rmse =  36100.19720043576

# %%
print("Random Forest Test mse = ",rf_mse_test," & mae = ",rf_mae_test," & rmse = ", sqrt(rf_mse_test))
# Out:
# Random Forest Test mse =  85196689307.87137  & mae =  155688.0580912863  & rmse =  291884.71920926485

# %%
test_data = {"Actual": y_test,
        "Predicted": predictions_test}
test_df = pd.DataFrame(test_data)

test_df["ratio"] = abs (test_df["Actual"] - test_df["Predicted"]) / test_df["Actual"]
test_df["Difference"] = abs(test_df["Actual"] - test_df["Predicted"])


train_data = {"Actual": y_train,
        "Predicted": predictions_train}
train_df = pd.DataFrame(train_data)

train_df["ratio"] = abs (train_df["Actual"] - train_df["Predicted"]) / train_df["Actual"]
train_df["Difference"] = abs(train_df["Actual"] - train_df["Predicted"])

comparison_df = pd.concat([test_df, train_df], axis = 0)

og_comparison_df = pd.concat([comparison_df, listings_df], axis = 1)

#og_comparison_df.head()

og_comparison_df.head()
# Out:
#            Actual  Predicted     ratio  Difference  \
# mls_id
# C7379048   849900     877000  0.031886       27100
# W8031016   529900     359900  0.320815      170000
# E7383362  1199000    1080000  0.099249      119000
# C6691040   529900     465000  0.122476       64900
# W7265218   721600     588888  0.183914      132712
#
#                                                         url  \
# mls_id
# C7379048  https://toronto.listing.ca/871-sheppard-ave-10...
# W8031016  https://toronto.listing.ca/830-lawrence-ave-26...
# E7383362  https://toronto.listing.ca/24-good-rd.E7383362...
# C6691040  https://toronto.listing.ca/715-don-mills-rd-26...
# W7265218  https://toronto.listing.ca/859-the-queensway-n...
#
#                             address    price  baths  beds  dens  \
# mls_id
# C7379048       871 Sheppard Ave 107   849900      3     2     0
# W8031016      830 Lawrence Ave 2609   529900      1     1     0
# E7383362                 24 Good Rd  1199000      4     3     0
# C6691040      715 Don Mills Rd 2606   529900      1     2     1
# W7265218  859 The Queensway N/A 212   721600      1     1     1
#
#                      street           neighbourhood     city    property_type  \
# mls_id
# C7379048       Sheppard Ave            Clanton Park  Toronto   condo_townhome
# W8031016       Lawrence Ave  Glenfield-Jane Heights  Toronto  condo_apartment
# E7383362            Good Rd          Highland Creek  Toronto    detached_home
# C6691040       Don Mills Rd         Flemingdon Park  Toronto  condo_apartment
# W7265218  The Queensway N/A     Stonegate-Queensway  Toronto  condo_apartment
#
#          date_scraped   latitude  longitude  rel_latitude  rel_longitude
# mls_id
# C7379048   2024-01-30  43.824060 -79.108054      0.824060      -0.108054
# W8031016   2024-01-30  43.714723 -79.454414      0.714723      -0.454414
# E7383362   2024-01-30  43.794732 -79.184112      0.794732      -0.184112
# C6691040   2024-01-30  43.710166 -79.334241      0.710166      -0.334241
# W7265218   2024-01-30  43.624217 -79.510284      0.624217      -0.510284

# %%
sorted_comparison = og_comparison_df.sort_values(by="ratio", ascending=False)
sorted_comparison.head()
# Out:
#            Actual  Predicted     ratio  Difference  \
# mls_id
# E8020546   949000    2500000  1.634352     1551000
# W8021980  1199000    2799000  1.334445     1600000
# C7280080  1559000    3500000  1.245029     1941000
# W7026116   598800    1199900  1.003841      601100
# W7406190  1499900    2999900  1.000067     1500000
#
#                                                         url  \
# mls_id
# E8020546  https://toronto.listing.ca/914-broadview-ave.E...
# W8021980  https://toronto.listing.ca/7-lorahill-rd.W8021...
# C7280080  https://toronto.listing.ca/227-ava-rd.C7280080...
# W7026116  https://toronto.listing.ca/630-rogers-rd-10.W7...
# W7406190  https://toronto.listing.ca/6-bonnyview-dr.W740...
#
#                     address    price  baths  beds  dens         street  \
# mls_id
# E8020546  914 Broadview Ave   949000      2     3     0  Broadview Ave
# W8021980      7 Lorahill Rd  1199000      2     3     1    Lorahill Rd
# C7280080         227 Ava Rd  1559000      2     3     2         Ava Rd
# W7026116   630 Rogers Rd 10   598800      2     2     0      Rogers Rd
# W7406190     6 Bonnyview Dr  1499900      2     3     1   Bonnyview Dr
#
#                      neighbourhood     city       property_type date_scraped  \
# mls_id
# E8020546  Playter Estates-Danforth  Toronto  freehold _townhome   2024-01-30
# W8021980       Stonegate-Queensway  Toronto       detached_home   2024-01-30
# C7280080        Humewood-Cedarvale  Toronto       detached_home   2024-01-30
# W7026116  Keelesdale-Eglinton West  Toronto      condo_townhome   2024-01-30
# W7406190       Stonegate-Queensway  Toronto       detached_home   2024-01-30
#
#            latitude  longitude  rel_latitude  rel_longitude
# mls_id
# E8020546  43.680560 -79.358018      0.680560      -0.358018
# W8021980  43.638038 -79.508740      0.638038      -0.508740
# C7280080  43.695450 -79.435762      0.695450      -0.435762
# W7026116  43.682079 -79.474374      0.682079      -0.474374
# W7406190  43.629187 -79.492364      0.629187      -0.492364

# %%
neigh_comparison = og_comparison_df.groupby("neighbourhood")

neigh_comparison["ratio"].mean().sort_values(ascending=False)
# Out:
# neighbourhood
# Playter Estates-Danforth         0.817176
# Keelesdale-Eglinton West         0.337283
# Pleasant View                    0.250417
# Weston-Pellam Park               0.217829
# Humewood-Cedarvale               0.163358
#                                    ...
# Thistletown-Beaumonde Heights    0.000000
# Woodbine Corridor                0.000000
# Forest Hill South                0.000000
# Wychwood                         0.000000
# Rustic                           0.000000
# Name: ratio, Length: 143, dtype: float64

# %%
sorted_comparison.loc[sorted_comparison["neighbourhood"] == "Banbury-Don Mills"]
# Out:
#            Actual  Predicted     ratio  Difference  \
# mls_id
# C7345696   849000     599000  0.294464      250000
# C7399662   829999     999000  0.203616      169001
# C7386200  2999990    3588000  0.196004      588010
# C8022108   739000     869000  0.175913      130000
# C8028886   749000     621888  0.169709      127112
# C8026230   539000     608000  0.128015       69000
# C7362550   699000     780000  0.115880       81000
# C8031008   580000     524900  0.095000       55100
# C7200462   689900     634900  0.079722       55000
# C7298294   598900     642900  0.073468       44000
# C7273774   739000     780000  0.055480       41000
# C8019722   549990     524900  0.045619       25090
# C7297786   634900     642900  0.012600        8000
# C7305092  1499333    1498800  0.000355         533
# C7320982   599000     599000  0.000000           0
# C7298206   642900     642900  0.000000           0
# C7347462   869000     869000  0.000000           0
# C7312728   599000     599000  0.000000           0
# C8015198   619000     619000  0.000000           0
# C7376454   621888     621888  0.000000           0
# C7273638  3300000    3300000  0.000000           0
# C8022288  3288000    3288000  0.000000           0
# C8012792   634900     634900  0.000000           0
# C7305546   579900     579900  0.000000           0
# C7378942   915513     915513  0.000000           0
# C8015346  2798000    2798000  0.000000           0
# C7309030  2600000    2600000  0.000000           0
# C8007366   579000     579000  0.000000           0
# C7282086   929000     929000  0.000000           0
# C8020160   608000     608000  0.000000           0
# C8028198  3399000    3399000  0.000000           0
# C6722750   959999     959999  0.000000           0
# C7292356  3588000    3588000  0.000000           0
# C7303204   729000     729000  0.000000           0
# C8028110   848000     848000  0.000000           0
# C7400404   498000     498000  0.000000           0
# C7053662     6980       6980  0.000000           0
# C7339364  1498800    1498800  0.000000           0
# C7230326   524900     524900  0.000000           0
# C7319898   999000     999000  0.000000           0
# C8010204   995000     995000  0.000000           0
# C7339894   780000     780000  0.000000           0
#
#                                                         url  \
# mls_id
# C7345696  https://toronto.listing.ca/18-concorde-pl-528....
# C7399662  https://toronto.listing.ca/181-wynford-dr-2409...
# C7386200  https://toronto.listing.ca/4-chipstead-rd.C738...
# C8022108  https://toronto.listing.ca/205-the-don-way-527...
# C8028886  https://toronto.listing.ca/181-wynford-dr-711....
# C8026230  https://toronto.listing.ca/120-dallimore-circ-...
# C7362550  https://toronto.listing.ca/5-concorde-pl-3102....
# C8031008  https://toronto.listing.ca/181-wynford-dr-1201...
# C7200462  https://toronto.listing.ca/99-the-donway-west-...
# C7298294  https://toronto.listing.ca/20-oneill-rd-233.C7...
# C7273774  https://toronto.listing.ca/135-wynford-dr-1203...
# C8019722  https://toronto.listing.ca/120-dallimore-circ-...
# C7297786  https://toronto.listing.ca/20-oneill-rd-1115.C...
# C7305092  https://toronto.listing.ca/48-chatfield-dr.C73...
# C7320982  https://toronto.listing.ca/18-concorde-pl-507....
# C7298206  https://toronto.listing.ca/20-oneill-rd-231.C7...
# C7347462  https://toronto.listing.ca/1210-don-mills-rd-4...
# C7312728  https://toronto.listing.ca/1103-leslie-st-409....
# C8015198  https://toronto.listing.ca/99-the-donway-423.C...
# C7376454  https://toronto.listing.ca/181-wynford-dr-2303...
# C7273638  https://toronto.listing.ca/27-southwell-dr.C72...
# C8022288  https://toronto.listing.ca/7-bamboo-grve.C8022...
# C8012792  https://toronto.listing.ca/1105-leslie-st-208....
# C7305546  https://toronto.listing.ca/133-wynford-dr-504....
# C7378942  https://toronto.listing.ca/17-dutch-myrtleway....
# C8015346  https://toronto.listing.ca/38-tangmere-rd.C801...
# C7309030  https://toronto.listing.ca/73-ames-circ.C73090...
# C8007366  https://toronto.listing.ca/1210-don-mills-rd-1...
# C7282086  https://toronto.listing.ca/1101-leslie-st-2006...
# C8020160  https://toronto.listing.ca/16-dallimore-circ-6...
# C8028198  https://toronto.listing.ca/48-caravan-dr.C8028...
# C6722750  https://toronto.listing.ca/1-concorde-pl-1204....
# C7292356  https://toronto.listing.ca/26-chatfield-dr.C72...
# C7303204  https://toronto.listing.ca/16-dallimore-circ-4...
# C8028110  https://toronto.listing.ca/12-burdock-lane.C80...
# C7400404  https://toronto.listing.ca/75-the-donway-1101....
# C7053662  https://toronto.listing.ca/65-ames-circ.C70536...
# C7339364  https://toronto.listing.ca/3-belton-rd.C733936...
# C7230326  https://toronto.listing.ca/7-concorde-pl-1410....
# C7319898  https://toronto.listing.ca/85-the-donway-n-a-1...
# C8010204  https://toronto.listing.ca/7-southill-dr-17.C8...
# C7339894  https://toronto.listing.ca/5-concorde-pl-301.C...
#
#                              address    price  baths  beds  dens  \
# mls_id
# C7345696          18 Concorde Pl 528   849000      2     2     0
# C7399662         181 Wynford Dr 2409   829999      2     3     0
# C7386200              4 Chipstead Rd  2999990      5     3     1
# C8022108         205 The Don Way 527   739000      4     2     0
# C8028886          181 Wynford Dr 711   749000      2     2     0
# C8026230      120 Dallimore Circ 124   539000      1     1     1
# C7362550          5 Concorde Pl 3102   699000      2     2     1
# C8031008         181 Wynford Dr 1201   580000      1     1     0
# C7200462  99 The Donway West N/A 525   689900      2     1     1
# C7298294           20 O'neill Rd 233   598900      1     1     0
# C7273774         135 Wynford Dr 1203   739000      2     2     1
# C8019722      120 Dallimore Circ 328   549990      1     2     0
# C7297786          20 O'neill Rd 1115   634900      1     1     0
# C7305092             48 Chatfield Dr  1499333      2     3     1
# C7320982          18 Concorde Pl 507   599000      2     2     0
# C7298206           20 O'neill Rd 231   642900      1     1     0
# C7347462       1210 Don Mills Rd 427   869000      2     2     0
# C7312728          1103 Leslie St 409   599000      1     1     1
# C8015198           99 The Donway 423   619000      1     1     0
# C7376454         181 Wynford Dr 2303   621888      2     2     0
# C7273638             27 Southwell Dr  3300000      3     3     1
# C8022288               7 Bamboo Grve  3288000      4     5     1
# C8012792          1105 Leslie St 208   634900      2     1     0
# C7305546          133 Wynford Dr 504   579900      1     1     1
# C7378942          17 Dutch Myrtleway   915513      4     3     0
# C8015346              38 Tangmere Rd  2798000      4     3     0
# C7309030                73 Ames Circ  2600000      4     4     1
# C8007366       1210 Don Mills Rd 121   579000      1     1     0
# C7282086         1101 Leslie St 2006   929000      2     2     0
# C8020160       16 Dallimore Circ 601   608000      1     1     1
# C8028198               48 Caravan Dr  3399000      4     5     1
# C6722750          1 Concorde Pl 1204   959999      3     2     1
# C7292356             26 Chatfield Dr  3588000      5     4     1
# C7303204       16 Dallimore Circ 418   729000      2     2     1
# C8028110             12 Burdock Lane   848000      2     3     0
# C7400404          75 The Donway 1101   498000      1     1     1
# C7053662                65 Ames Circ     6980      5     5     2
# C7339364                 3 Belton Rd  1498800      2     3     1
# C7230326          7 Concorde Pl 1410   524900      1     1     0
# C7319898      85 The Donway N/A 1004   999000      2     3     0

# %%
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
file = "listings_with_locations.csv"

file_path = Path("data/" + file)
listings_df = pd.read_csv(file_path, index_col="mls_id", header=0)


listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude
# mls_id
# E8018446  43.687469 -79.301861
# C7266728  43.650343 -79.387806
# W7239426  43.622946 -79.481658
# E8030950  43.658361 -79.351159
# E8030860  43.665267 -79.341034

# %%
listings_df = listings_df[(listings_df['baths'] != 0)]

listings_df = listings_df.dropna(subset=["latitude"])

# %%
listings_df['rel_latitude'] = listings_df['latitude'] - 43
listings_df['rel_longitude'] = listings_df['longitude'] + 79

listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude  rel_latitude  rel_longitude
# mls_id
# E8018446  43.687469 -79.301861      0.687469      -0.301861
# C7266728  43.650343 -79.387806      0.650343      -0.387806
# W7239426  43.622946 -79.481658      0.622946      -0.481658
# E8030950  43.658361 -79.351159      0.658361      -0.351159
# E8030860  43.665267 -79.341034      0.665267      -0.341034

# %%
# #Choosing 500 as a cutoff value
# neighbourhoods_to_replace = []
# for value, count in listings_df['neighbourhood'].value_counts().items():
#   if count < 20:
#     neighbourhoods_to_replace.append(value)

# # Replace in dataframe
# for app in neighbourhoods_to_replace:
#     listings_df['neighbourhood'] = listings_df['neighbourhood'].replace(app,"Other")

# # Check to make sure binning was successful
# #listings_df['neighbourhood'].value_counts()

# %%
cat_columns = ["neighbourhood", "property_type"]
num_columns = ["baths", "beds", "dens", "rel_latitude", "rel_longitude"]
y = listings_df["price"]

# %%
listings_df_prepared = pd.get_dummies(listings_df[cat_columns], dtype=int)
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt North  \
# mls_id
# E8018446                              0
# C7266728                              0
# W7239426                              0
# E8030950                              0
# E8030860                              0
#
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# E8018446                                           0                        0
# C7266728                                           0                        0
# W7239426                                           0                        0
# E8030950                                           0                        0
# E8030860                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# E8018446                    0                                0
# C7266728                    0                                0
# W7239426                    0                                0
# E8030950                    0                                0
# E8030860                    0                                0
#
#           neighbourhood_Bathurst Manor  neighbourhood_Bay Street Corridor  \
# mls_id
# E8018446                             0                                  0
# C7266728                             0                                  0
# W7239426                             0                                  0
# E8030950                             0                                  0
# E8030860                             0                                  0
#
#           neighbourhood_Bayview Village  neighbourhood_Bayview Woods-Steeles  \
# mls_id
# E8018446                              0                                    0
# C7266728                              0                                    0
# W7239426                              0                                    0
# E8030950                              0                                    0
# E8030860                              0                                    0
#
#           neighbourhood_Bedford Park-Nortown  ...  \
# mls_id                                        ...
# E8018446                                   0  ...
# C7266728                                   0  ...
# W7239426                                   0  ...
# E8030950                                   0  ...
# E8030860                                   0  ...
#
#           neighbourhood_Woodbine-Lumsden  neighbourhood_Wychwood  \
# mls_id
# E8018446                               0                       0
# C7266728                               0                       0
# W7239426                               0                       0
# E8030950                               0                       0
# E8030860                               0                       0
#
#           neighbourhood_Yonge-Eglinton  neighbourhood_Yonge-St. Clair  \
# mls_id
# E8018446                             0                              0
# C7266728                             0                              0
# W7239426                             0                              0
# E8030950                             0                              0
# E8030860                             0                              0
#
#           neighbourhood_York University Heights  \
# mls_id
# E8018446                                      0
# C7266728                                      0
# W7239426                                      0
# E8030950                                      0
# E8030860                                      0
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# E8018446                                 0                              1
# C7266728                                 0                              1
# W7239426                                 0                              1
# E8030950                                 0                              1
# E8030860                                 0                              1
#
#           property_type_condo_townhome  property_type_detached_home  \
# mls_id
# E8018446                             0                            0
# C7266728                             0                            0
# W7239426                             0                            0
# E8030950                             0                            0
# E8030860                             0                            0
#
#           property_type_freehold _townhome
# mls_id
# E8018446                                 0
# C7266728                                 0
# W7239426                                 0
# E8030950                                 0
# E8030860                                 0
#
# [5 rows x 147 columns]

# %%
listings_df_prepared[num_columns] = listings_df[num_columns]
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt North  \
# mls_id
# E8018446                              0
# C7266728                              0
# W7239426                              0
# E8030950                              0
# E8030860                              0
#
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# E8018446                                           0                        0
# C7266728                                           0                        0
# W7239426                                           0                        0
# E8030950                                           0                        0
# E8030860                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# E8018446                    0                                0
# C7266728                    0                                0
# W7239426                    0                                0
# E8030950                    0                                0
# E8030860                    0                                0
#
#           neighbourhood_Bathurst Manor  neighbourhood_Bay Street Corridor  \
# mls_id
# E8018446                             0                                  0
# C7266728                             0                                  0
# W7239426                             0                                  0
# E8030950                             0                                  0
# E8030860                             0                                  0
#
#           neighbourhood_Bayview Village  neighbourhood_Bayview Woods-Steeles  \
# mls_id
# E8018446                              0                                    0
# C7266728                              0                                    0
# W7239426                              0                                    0
# E8030950                              0                                    0
# E8030860                              0                                    0
#
#           neighbourhood_Bedford Park-Nortown  ...  \
# mls_id                                        ...
# E8018446                                   0  ...
# C7266728                                   0  ...
# W7239426                                   0  ...
# E8030950                                   0  ...
# E8030860                                   0  ...
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# E8018446                                 0                              1
# C7266728                                 0                              1
# W7239426                                 0                              1
# E8030950                                 0                              1
# E8030860                                 0                              1
#
#           property_type_condo_townhome  property_type_detached_home  \
# mls_id
# E8018446                             0                            0
# C7266728                             0                            0
# W7239426                             0                            0
# E8030950                             0                            0
# E8030860                             0                            0
#
#           property_type_freehold _townhome  baths  beds  dens  rel_latitude  \
# mls_id
# E8018446                                 0      1     1     1      0.687469
# C7266728                                 0      1     1     0      0.650343
# W7239426                                 0      1     1     1      0.622946
# E8030950                                 0      2     2     0      0.658361
# E8030860                                 0      1     1     0      0.665267
#
#           rel_longitude
# mls_id
# E8018446      -0.301861
# C7266728      -0.387806
# W7239426      -0.481658
# E8030950      -0.351159
# E8030860      -0.341034
#
# [5 rows x 152 columns]

# %%
X = listings_df_prepared

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
rf_model = RandomForestClassifier(n_estimators=500, random_state=1)

rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions_train = rf_model.predict(X_train_scaled)

# %%
predictions_test = rf_model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
rf_mse_train = mean_squared_error(y_train, predictions_train)
rf_mae_train = mean_absolute_error(y_train, predictions_train)

rf_mse_test = mean_squared_error(y_test, predictions_test)
rf_mae_test = mean_absolute_error(y_test, predictions_test)

# %%
from math import sqrt

# %%
print("Random Forest Train mse = ",rf_mse_train," & mae = ",rf_mae_train," & rmse = ", sqrt(rf_mse_train))
# Out:
# Random Forest Train mse =  16249864466.641062  & mae =  16554.669302456932  & rmse =  127474.9562331404

# %%
print("Random Forest Test mse = ",rf_mse_test," & mae = ",rf_mae_test," & rmse = ", sqrt(rf_mse_test))
# Out:
# Random Forest Test mse =  2534276591987.4507  & mae =  446409.4149026249  & rmse =  1591941.1396114652

# %%
test_data = {"Actual": y_test,
        "Predicted": predictions_test}
test_df = pd.DataFrame(test_data)

test_df["ratio"] = abs (test_df["Actual"] - test_df["Predicted"]) / test_df["Actual"]
test_df["Difference"] = abs(test_df["Actual"] - test_df["Predicted"])


train_data = {"Actual": y_train,
        "Predicted": predictions_train}
train_df = pd.DataFrame(train_data)

train_df["ratio"] = abs (train_df["Actual"] - train_df["Predicted"]) / train_df["Actual"]
train_df["Difference"] = abs(train_df["Actual"] - train_df["Predicted"])

comparison_df = pd.concat([test_df, train_df], axis = 0)

og_comparison_df = pd.concat([comparison_df, listings_df], axis = 1)

#og_comparison_df.head()

og_comparison_df.head()
# Out:
#            Actual  Predicted     ratio  Difference  \
# mls_id
# C7385816  1348000    5500000  3.080119     4152000
# C7384564   825000    1275000  0.545455      450000
# C7375126   995888     938000  0.058127       57888
# C7267212   649000     570000  0.121726       79000
# E7300824   499500     425000  0.149149       74500
#
#                                                         url  \
# mls_id
# C7385816  https://toronto.listing.ca/70-hargrave-lane-7....
# C7384564  https://toronto.listing.ca/120-bayview-ave-n10...
# C7375126  https://toronto.listing.ca/887-bay-st-1106.C73...
# C7267212  https://toronto.listing.ca/33-helendale-ave-21...
# E7300824  https://toronto.listing.ca/20-gilder-dr-905.E7...
#
#                         address    price  baths  beds  dens         street  \
# mls_id
# C7385816     70 Hargrave Lane 7  1348000      3     3     0  Hargrave Lane
# C7384564  120 Bayview Ave N1009   825000      2     2     0    Bayview Ave
# C7375126        887 Bay St 1106   995888      2     2     0         Bay St
# C7267212  33 Helendale Ave 2101   649000      1     2     0  Helendale Ave
# E7300824       20 Gilder Dr 905   499500      1     2     0      Gilder Dr
#
#                               neighbourhood     city    property_type  \
# mls_id
# C7385816  Bridle Path-Sunnybrook-York Mills  Toronto   condo_townhome
# C7384564          Waterfront Communities C8  Toronto  condo_apartment
# C7375126                Bay Street Corridor  Toronto  condo_apartment
# C7267212                     Yonge-Eglinton  Toronto  condo_apartment
# E7300824                      Eglinton East  Toronto  condo_apartment
#
#          date_scraped   latitude  longitude  rel_latitude  rel_longitude
# mls_id
# C7385816   2024-01-30  43.722366 -79.379318      0.722366      -0.379318
# C7384564   2024-01-30  43.725840 -79.380580      0.725840      -0.380580
# C7375126   2024-01-30  43.662983 -79.386292      0.662983      -0.386292
# C7267212   2024-01-30  43.708715 -79.399383      0.708715      -0.399383
# E7300824   2024-01-30  43.736498 -79.257993      0.736498      -0.257993

# %%
sorted_comparison = og_comparison_df.sort_values(by="ratio", ascending=False)
sorted_comparison.head(20)
# Out:
#            Actual  Predicted     ratio  Difference  \
# mls_id
# C7402374  1144800    6645000  4.804507     5500200
# C8021488   999000    5500000  4.505506     4501000
# C7063270  2125000    9500000  3.470588     7375000
# C7385816  1348000    5500000  3.080119     4152000
# C5939643  7500000   28000000  2.733333    20500000
# C8022942  2395000    8325000  2.475992     5930000
# C7259238  1685000    5590000  2.317507     3905000
# C7045680  1499000    4595000  2.065377     3096000
# C7275918  5399000   16500000  2.056122    11101000
# C7302848  7880000   23500000  1.982234    15620000
# C7342786   759900    2259000  1.972760     1499100
# C7048374  7995000   22500000  1.814259    14505000
# W8010980  1288800    3389999  1.630353     2101199
# C7235918   698000    1748888  1.505570     1050888
# C7402098  2995000    7500000  1.504174     4505000
# C8014774  4525000   10995000  1.429834     6470000
# C8028854  1975000    4785000  1.422785     2810000
# C7304752   450000    1088000  1.417778      638000
# C7240112   869000    2098000  1.414269     1229000
# W8007328   799000    1849990  1.315382     1050990
#
#                                                         url  \
# mls_id
# C7402374  https://toronto.listing.ca/250-lawrence-ave-90...
# C8021488  https://toronto.listing.ca/70-hargrave-lane-12...
# C7063270  https://toronto.listing.ca/300-front-st-4404.C...
# C7385816  https://toronto.listing.ca/70-hargrave-lane-7....
# C5939643  https://toronto.listing.ca/19-royal-oak-dr.C59...
# C8022942  https://toronto.listing.ca/111-st-clair-ave-81...
# C7259238  https://toronto.listing.ca/102-bloor-st-ph6.C7...
# C7045680  https://toronto.listing.ca/1001-bay-st-ph02.C7...
# C7275918  https://toronto.listing.ca/111-roxborough-dr.C...
# C7302848  https://toronto.listing.ca/311-bay-st-4801.C73...
# C7342786  https://toronto.listing.ca/36-charlotte-st-705...
# C7048374  https://toronto.listing.ca/9-post-rd.C7048374....
# W8010980  https://toronto.listing.ca/1128-glengrove-ave....
# C7235918  https://toronto.listing.ca/44-gerrard-st-1402....
# C7402098  https://toronto.listing.ca/6-boulton-dr.C74020...
# C8014774  https://toronto.listing.ca/72-glengowan-rd.C80...
# C8028854  https://toronto.listing.ca/55-avenue-rd-406.C8...
# C7304752  https://toronto.listing.ca/581-avenue-rd-404.C...
# C7240112  https://toronto.listing.ca/35-balmuto-st-2104....
# W8007328  https://toronto.listing.ca/45-southport-st-150...
#
#                        address    price  baths  beds  dens         street  \
# mls_id
# C7402374  250 Lawrence Ave 907  1144800      2     2     0   Lawrence Ave
# C8021488   70 Hargrave Lane 12   999000      3     3     1  Hargrave Lane
# C7063270     300 Front St 4404  2125000      3     2     1       Front St
# C7385816    70 Hargrave Lane 7  1348000      3     3     0  Hargrave Lane
# C5939643       19 Royal Oak Dr  7500000      9     7     0   Royal Oak Dr
# C8022942  111 St Clair Ave 819  2395000      4     3     0   St Clair Ave
# C7259238      102 Bloor St Ph6  1685000      3     2     0       Bloor St
# C7045680      1001 Bay St Ph02  1499000      3     2     1         Bay St
# C7275918     111 Roxborough Dr  5399000      4     4     1  Roxborough Dr
# C7302848       311 Bay St 4801  7880000      5     3     0         Bay St
# C7342786   36 Charlotte St 705   759900      2     1     0   Charlotte St
# C7048374             9 Post Rd  7995000     10     7     1        Post Rd
# W8010980    1128 Glengrove Ave  1288800      4     3     0  Glengrove Ave
# C7235918    44 Gerrard St 1402   698000      1     3     1     Gerrard St
# C7402098          6 Boulton Dr  2995000      5     7     2     Boulton Dr
# C8014774       72 Glengowan Rd  4525000      5     5     1   Glengowan Rd
# C8028854      55 Avenue Rd 406  1975000      3     2     0      Avenue Rd
# C7304752     581 Avenue Rd 404   450000      1     1     0      Avenue Rd
# C7240112    35 Balmuto St 2104   869000      2     1     1     Balmuto St
# W8007328  45 Southport St 1504   799000      2     3     0   Southport St
#
#                               neighbourhood     city    property_type  \
# mls_id
# C7402374                Lawrence Park North  Toronto  condo_apartment
# C8021488  Bridle Path-Sunnybrook-York Mills  Toronto   condo_townhome
# C7063270          Waterfront Communities C1  Toronto  condo_apartment
# C7385816  Bridle Path-Sunnybrook-York Mills  Toronto   condo_townhome
# C5939643  Bridle Path-Sunnybrook-York Mills  Toronto    detached_home
# C8022942                    Yonge-St. Clair  Toronto  condo_apartment
# C7259238                              Annex  Toronto  condo_apartment
# C7045680                Bay Street Corridor  Toronto  condo_apartment
# C7275918                Rosedale-Moore Park  Toronto    detached_home
# C7302848          Waterfront Communities C1  Toronto  condo_apartment
# C7342786          Waterfront Communities C1  Toronto  condo_apartment
# C7048374  Bridle Path-Sunnybrook-York Mills  Toronto    detached_home
# W8010980                 Yorkdale-Glen Park  Toronto    detached_home
# C7235918                Bay Street Corridor  Toronto  condo_apartment
# C7402098                          Casa Loma  Toronto    detached_home
# C8014774                Lawrence Park South  Toronto    detached_home
# C8028854                              Annex  Toronto  condo_apartment
# C7304752                    Yonge-St. Clair  Toronto  condo_apartment
# C7240112                Bay Street Corridor  Toronto  condo_apartment
# W8007328                  High Park-Swansea  Toronto  condo_apartment
#
#          date_scraped   latitude  longitude  rel_latitude  rel_longitude
# mls_id
# C7402374   2024-01-30  43.722700 -79.414192      0.722700      -0.414192
# C8021488   2024-01-30  43.722366 -79.379318      0.722366      -0.379318
# C7063270   2024-01-30  43.643985 -79.389342      0.643985      -0.389342
# C7385816   2024-01-30  43.722366 -79.379318      0.722366      -0.379318
# C5939643   2024-01-30  43.727970 -79.361178      0.727970      -0.361178
# C8022942   2024-01-30  43.686798 -79.399072      0.686798      -0.399072
# C7259238   2024-01-30  43.669402 -79.391644      0.669402      -0.391644
# C7045680   2024-01-30  43.665360 -79.387202      0.665360      -0.387202
# C7275918   2024-01-30  43.682277 -79.376451      0.682277      -0.376451
# C7302848   2024-01-30  43.649755 -79.380323      0.649755      -0.380323
# C7342786   2024-01-30  43.646561 -79.394151      0.646561      -0.394151
# C7048374   2024-01-30  43.736910 -79.378562      0.736910      -0.378562
# W8010980   2024-01-30  43.707335 -79.461686      0.707335      -0.461686
# C7235918   2024-01-30  43.658939 -79.383827      0.658939      -0.383827
# C7402098   2024-01-30  43.677216 -79.403276      0.677216      -0.403276
# C8014774   2024-01-30  43.721181 -79.391498      0.721181      -0.391498
# C8028854   2024-01-30  43.671154 -79.394998      0.671154      -0.394998
# C7304752   2024-01-30  43.688952 -79.401999      0.688952      -0.401999
# C7240112   2024-01-30  43.669496 -79.387417      0.669496      -0.387417
# W8007328   2024-01-30  43.640048 -79.474379      0.640048      -0.474379

# %%
neigh_comparison = og_comparison_df.groupby("neighbourhood")

neigh_comparison["ratio"].mean().sort_values(ascending=False)
# Out:
# neighbourhood
# Lawrence Park North                  0.542845
# Bridle Path-Sunnybrook-York Mills    0.534552
# Yonge-St. Clair                      0.271191
# Woodbine Corridor                    0.166578
# Lawrence Park South                  0.163018
#                                        ...
# Keelesdale-Eglinton West             0.000000
# Blake-Jones                          0.000000
# Rexdale-Kipling                      0.000000
# Playter Estates-Danforth             0.000000
# Pleasant View                        0.000000
# Name: ratio, Length: 143, dtype: float64

# %%
annex_df = og_comparison_df.loc[og_comparison_df['neighbourhood']=="Annex", :]

annex_df["price"].max()
# Out:
# 9999000

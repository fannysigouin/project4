# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline

# %%
# Load data
file = "listings_with_locations.csv"

file_path = Path("data/" + file)
listings_df = pd.read_csv(file_path, index_col="mls_id", header=0)


listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude
# mls_id
# E8018446  43.687469 -79.301861
# C7266728  43.650343 -79.387806
# W7239426  43.622946 -79.481658
# E8030950  43.658361 -79.351159
# E8030860  43.665267 -79.341034

# %%
# Remove luxury listings with more than 5 bathrooms or more than 4 beds 
listings_df = listings_df[(listings_df['baths'] != 0) & (listings_df['baths'] <= 5) & (listings_df['beds'] <= 4) & (listings_df['beds'] != 0) & (listings_df['dens'] <= 2)]

# Remove rows with missing latitude values
listings_df = listings_df.dropna(subset=["latitude"])

# %%
# Function to remove outliers (IQR)
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers for each property type

for i in range(4):
    cleaned_df = pd.DataFrame()
    for property_type in listings_df['property_type'].unique():
        subset_df = listings_df[listings_df['property_type'] == property_type]
        cleaned_subset = remove_outliers(subset_df, 'price')
        cleaned_df = pd.concat([cleaned_df, cleaned_subset])
    listings_df = cleaned_df

# %%
listings_df.count()
# Out:
# url              3658
# address          3658
# price            3658
# baths            3658
# beds             3658
# dens             3658
# street           3658
# neighbourhood    3658
# city             3658
# property_type    3658
# date_scraped     3658
# latitude         3658
# longitude        3658
# dtype: int64

# %%
# Feature engineering
listings_df['rel_latitude'] = listings_df['latitude'] - 43
listings_df['rel_longitude'] = listings_df['longitude'] + 79

listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude  rel_latitude  rel_longitude
# mls_id
# E8018446  43.687469 -79.301861      0.687469      -0.301861
# C7266728  43.650343 -79.387806      0.650343      -0.387806
# W7239426  43.622946 -79.481658      0.622946      -0.481658
# E8030950  43.658361 -79.351159      0.658361      -0.351159
# E8030860  43.665267 -79.341034      0.665267      -0.341034

# %%
listings_df.nunique()
# Out:
# url              3658
# address          3654
# price            1088
# baths               5
# beds                4
# dens                3
# street           1141
# neighbourhood     143
# city                1
# property_type       4
# date_scraped        1
# latitude         2078
# longitude        2079
# rel_latitude     2078
# rel_longitude    2079
# dtype: int64

# %%
listings_df['neighbourhood'].value_counts()
# Out:
# Waterfront Communities C1            332
# Church-Yonge Corridor                189
# Mimico                               153
# Islington-City Centre West           118
# Willowdale East                      115
#                                     ...
# Lambton Baby Point                     3
# Pleasant View                          2
# Bridle Path-Sunnybrook-York Mills      2
# Forest Hill South                      1
# Playter Estates-Danforth               1
# Name: neighbourhood, Length: 143, dtype: int64

# %%
# Prepare data for training
cat_columns = ["neighbourhood", "property_type"]
num_columns = ["baths", "beds", "dens", "rel_latitude", "rel_longitude"]
y = listings_df["price"]

# %%
listings_df_prepared = pd.get_dummies(listings_df[cat_columns], dtype=int)
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt North  \
# mls_id
# E8018446                              0
# C7266728                              0
# W7239426                              0
# E8030950                              0
# E8030860                              0
#
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# E8018446                                           0                        0
# C7266728                                           0                        0
# W7239426                                           0                        0
# E8030950                                           0                        0
# E8030860                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# E8018446                    0                                0
# C7266728                    0                                0
# W7239426                    0                                0
# E8030950                    0                                0
# E8030860                    0                                0
#
#           neighbourhood_Bathurst Manor  neighbourhood_Bay Street Corridor  \
# mls_id
# E8018446                             0                                  0
# C7266728                             0                                  0
# W7239426                             0                                  0
# E8030950                             0                                  0
# E8030860                             0                                  0
#
#           neighbourhood_Bayview Village  neighbourhood_Bayview Woods-Steeles  \
# mls_id
# E8018446                              0                                    0
# C7266728                              0                                    0
# W7239426                              0                                    0
# E8030950                              0                                    0
# E8030860                              0                                    0
#
#           neighbourhood_Bedford Park-Nortown  ...  \
# mls_id                                        ...
# E8018446                                   0  ...
# C7266728                                   0  ...
# W7239426                                   0  ...
# E8030950                                   0  ...
# E8030860                                   0  ...
#
#           neighbourhood_Woodbine-Lumsden  neighbourhood_Wychwood  \
# mls_id
# E8018446                               0                       0
# C7266728                               0                       0
# W7239426                               0                       0
# E8030950                               0                       0
# E8030860                               0                       0
#
#           neighbourhood_Yonge-Eglinton  neighbourhood_Yonge-St. Clair  \
# mls_id
# E8018446                             0                              0
# C7266728                             0                              0
# W7239426                             0                              0
# E8030950                             0                              0
# E8030860                             0                              0
#
#           neighbourhood_York University Heights  \
# mls_id
# E8018446                                      0
# C7266728                                      0
# W7239426                                      0
# E8030950                                      0
# E8030860                                      0
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# E8018446                                 0                              1
# C7266728                                 0                              1
# W7239426                                 0                              1
# E8030950                                 0                              1
# E8030860                                 0                              1
#
#           property_type_condo_townhome  property_type_detached_home  \
# mls_id
# E8018446                             0                            0
# C7266728                             0                            0
# W7239426                             0                            0
# E8030950                             0                            0
# E8030860                             0                            0
#
#           property_type_freehold _townhome
# mls_id
# E8018446                                 0
# C7266728                                 0
# W7239426                                 0
# E8030950                                 0
# E8030860                                 0
#
# [5 rows x 147 columns]

# %%
listings_df_prepared[num_columns] = listings_df[num_columns]
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt North  \
# mls_id
# E8018446                              0
# C7266728                              0
# W7239426                              0
# E8030950                              0
# E8030860                              0
#
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# E8018446                                           0                        0
# C7266728                                           0                        0
# W7239426                                           0                        0
# E8030950                                           0                        0
# E8030860                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# E8018446                    0                                0
# C7266728                    0                                0
# W7239426                    0                                0
# E8030950                    0                                0
# E8030860                    0                                0
#
#           neighbourhood_Bathurst Manor  neighbourhood_Bay Street Corridor  \
# mls_id
# E8018446                             0                                  0
# C7266728                             0                                  0
# W7239426                             0                                  0
# E8030950                             0                                  0
# E8030860                             0                                  0
#
#           neighbourhood_Bayview Village  neighbourhood_Bayview Woods-Steeles  \
# mls_id
# E8018446                              0                                    0
# C7266728                              0                                    0
# W7239426                              0                                    0
# E8030950                              0                                    0
# E8030860                              0                                    0
#
#           neighbourhood_Bedford Park-Nortown  ...  \
# mls_id                                        ...
# E8018446                                   0  ...
# C7266728                                   0  ...
# W7239426                                   0  ...
# E8030950                                   0  ...
# E8030860                                   0  ...
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# E8018446                                 0                              1
# C7266728                                 0                              1
# W7239426                                 0                              1
# E8030950                                 0                              1
# E8030860                                 0                              1
#
#           property_type_condo_townhome  property_type_detached_home  \
# mls_id
# E8018446                             0                            0
# C7266728                             0                            0
# W7239426                             0                            0
# E8030950                             0                            0
# E8030860                             0                            0
#
#           property_type_freehold _townhome  baths  beds  dens  rel_latitude  \
# mls_id
# E8018446                                 0      1     1     1      0.687469
# C7266728                                 0      1     1     0      0.650343
# W7239426                                 0      1     1     1      0.622946
# E8030950                                 0      2     2     0      0.658361
# E8030860                                 0      1     1     0      0.665267
#
#           rel_longitude
# mls_id
# E8018446      -0.301861
# C7266728      -0.387806
# W7239426      -0.481658
# E8030950      -0.351159
# E8030860      -0.341034
#
# [5 rows x 152 columns]

# %%
X = listings_df_prepared
y = listings_df["price"]

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a pipeline with StandardScaler and RandomForestRegressor
rf_pipeline = make_pipeline(StandardScaler(), RandomForestRegressor(n_estimators=500, random_state=1))

# %%
# Train the model and evaluate it using cross-validation
cv_scores = cross_val_score(rf_pipeline, X_train, y_train, cv=5, scoring='neg_mean_absolute_error')

print("Cross-Validation MAE Scores:", -cv_scores)
print("Mean CV MAE:", -cv_scores.mean())
# Out:
# Cross-Validation MAE Scores: [105309.29443354 103889.95290712 102980.0790088  113227.96274505
#  105141.73815739 108332.26017879 121621.64615524 117378.02015854
#  128127.18344849 120376.79284492]
# Mean CV MAE: 112638.49300378762

# %%
# Fit the model on the training set
rf_pipeline.fit(X_train, y_train)

# Make predictions on the test set
predictions_test = rf_pipeline.predict(X_test)

# %%
# Evaluate the model on the test set
rf_mae_test = mean_absolute_error(y_test, predictions_test)
print("Random Forest Test MAE:", rf_mae_test)
# Out:
# Random Forest Test MAE: 107851.1773061482

# %%
# Make predictions on the training set
predictions_train = rf_pipeline.predict(X_train)

# %%
test_data = {"Actual": y_test,
        "Predicted": predictions_test}
test_df = pd.DataFrame(test_data)

test_df["ratio"] = abs (test_df["Actual"] - test_df["Predicted"]) / test_df["Actual"]
test_df["Difference"] = abs(test_df["Actual"] - test_df["Predicted"])


train_data = {"Actual": y_train,
        "Predicted": predictions_train}
train_df = pd.DataFrame(train_data)

train_df["ratio"] = abs (train_df["Actual"] - train_df["Predicted"]) / train_df["Actual"]
train_df["Difference"] = abs(train_df["Actual"] - train_df["Predicted"])

comparison_df = pd.concat([test_df, train_df], axis = 0)

og_comparison_df = pd.concat([comparison_df, listings_df], axis = 1)

og_comparison_df.head()
# Out:
#            Actual     Predicted     ratio     Difference  \
# mls_id
# E7392872   525000  5.041877e+05  0.039643   20812.315333
# C7403516   649000  6.790014e+05  0.046227   30001.355733
# W7398652  1235000  1.334841e+06  0.080843   99841.086000
# E7345710  1198800  1.098083e+06  0.084015  100717.432000
# E7266274   674900  5.942272e+05  0.119533   80672.775905
#
#                                                         url  \
# mls_id
# E7392872  https://toronto.listing.ca/3311-kingston-rd-14...
# C7403516  https://toronto.listing.ca/260-seneca-hill-dr-...
# W7398652  https://toronto.listing.ca/80-amesbury-dr.W739...
# E7345710  https://toronto.listing.ca/15-stonehenge-cres....
# E7266274  https://toronto.listing.ca/4727-sheppard-ave-1...
#
#                          address    price  baths  beds  dens           street  \
# mls_id
# E7392872   3311 Kingston Rd 1409   525000      1     2     0      Kingston Rd
# C7403516  260 Seneca Hill Dr 912   649000      1     2     0   Seneca Hill Dr
# W7398652          80 Amesbury Dr  1235000      3     3     1      Amesbury Dr
# E7345710      15 Stonehenge Cres  1198800      2     3     2  Stonehenge Cres
# E7266274  4727 Sheppard Ave 1501   674900      2     2     1     Sheppard Ave
#
#                          neighbourhood     city    property_type date_scraped  \
# mls_id
# E7392872           Scarborough Village  Toronto  condo_apartment   2024-01-30
# C7403516            Don Valley Village  Toronto  condo_apartment   2024-01-30
# W7398652           Brookhaven-Amesbury  Toronto    detached_home   2024-01-30
# E7345710                        Woburn  Toronto    detached_home   2024-01-30
# E7266274  Agincourt South-Malvern West  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude  rel_latitude  rel_longitude
# mls_id
# E7392872  43.733320 -79.222392      0.733320      -0.222392
# C7403516  43.790149 -79.357271      0.790149      -0.357271
# W7398652  43.705257 -79.482238      0.705257      -0.482238
# E7345710  43.770728 -79.226503      0.770728      -0.226503
# E7266274  43.791598 -79.248969      0.791598      -0.248969

# %%
sorted_comparison = og_comparison_df.sort_values(by="ratio", ascending=False)
sorted_comparison.head()
# Out:
#            Actual     Predicted     ratio    Difference  \
# mls_id
# W7301712  1149000  2.453916e+06  1.135697  1.304916e+06
# W7250092   439900  8.131211e+05  0.848423  3.732211e+05
# W7374132   949999  1.749320e+06  0.841391  7.993206e+05
# W7380994  1325000  2.415641e+06  0.823125  1.090641e+06
# E8028440   974888  1.744762e+06  0.789705  7.698735e+05
#
#                                                         url  \
# mls_id
# W7301712  https://toronto.listing.ca/4-monaco-crt.W73017...
# W7250092  https://toronto.listing.ca/320-dixon-rd-115.W7...
# W7374132  https://toronto.listing.ca/81-woolenscote-circ...
# W7380994  https://toronto.listing.ca/27-craydon-ave.W738...
# E8028440  https://toronto.listing.ca/20-murmouth-rd.E802...
#
#                       address    price  baths  beds  dens            street  \
# mls_id
# W7301712         4 Monaco Crt  1149000      5     4     1        Monaco Crt
# W7250092     320 Dixon Rd 115   439900      2     3     0          Dixon Rd
# W7374132  81 Woolenscote Circ   949999      4     3     2  Woolenscote Circ
# W7380994       27 Craydon Ave  1325000      5     3     0       Craydon Ave
# E8028440       20 Murmouth Rd   974888      2     3     0       Murmouth Rd
#
#                           neighbourhood     city    property_type  \
# mls_id
# W7301712                    Black Creek  Toronto    detached_home
# W7250092  Kingsview Village-The Westway  Toronto  condo_apartment
# W7374132         West Humber-Clairville  Toronto    detached_home
# W7380994                   Mount Dennis  Toronto    detached_home
# E8028440         Tam O'Shanter-Sullivan  Toronto    detached_home
#
#          date_scraped   latitude  longitude  rel_latitude  rel_longitude
# mls_id
# W7301712   2024-01-30  43.765226 -79.528315      0.765226      -0.528315
# W7250092   2024-01-30  43.696811 -79.552502      0.696811      -0.552502
# W7374132   2024-01-30  43.732734 -79.602049      0.732734      -0.602049
# W7380994   2024-01-30  43.690797 -79.497534      0.690797      -0.497534
# E8028440   2024-01-30  43.777314 -79.294474      0.777314      -0.294474

# %%
# Neighbourhood ratios (margin of error)
neigh_comparison = og_comparison_df.groupby("neighbourhood")

neigh_comparison["ratio"].mean().sort_values(ascending=False)
# Out:
# neighbourhood
# Corso Italia-Davenport      0.244090
# Mount Dennis                0.171992
# Black Creek                 0.162954
# Playter Estates-Danforth    0.161109
# Pleasant View               0.160248
#                               ...
# Bendale                     0.032421
# Dorset Park                 0.031512
# Kensington-Chinatown        0.031254
# Bayview Woods-Steeles       0.030776
# Ionview                     0.015568
# Name: ratio, Length: 143, dtype: float64

# %%
sorted_comparison.loc[sorted_comparison["neighbourhood"] == "Corso Italia-Davenport"]
# Out:
#            Actual    Predicted     ratio  Difference  \
# mls_id
# W8028100   995000  1382025.696  0.388971  387025.696
# W8031028   849000  1056897.146  0.244873  207897.146
# W7390820  1899000  1712086.728  0.098427  186913.272
#
#                                                         url  \
# mls_id
# W8028100  https://toronto.listing.ca/1240-lansdowne-ave....
# W8031028  https://toronto.listing.ca/146-ascot-ave.W8031...
# W7390820  https://toronto.listing.ca/127-greenlaw-ave.W7...
#
#                      address    price  baths  beds  dens         street  \
# mls_id
# W8028100  1240 Lansdowne Ave   995000      3     4     0  Lansdowne Ave
# W8031028       146 Ascot Ave   849000      1     2     0      Ascot Ave
# W7390820    127 Greenlaw Ave  1899000      3     3     1   Greenlaw Ave
#
#                    neighbourhood     city       property_type date_scraped  \
# mls_id
# W8028100  Corso Italia-Davenport  Toronto  freehold _townhome   2024-01-30
# W8031028  Corso Italia-Davenport  Toronto       detached_home   2024-01-30
# W7390820  Corso Italia-Davenport  Toronto       detached_home   2024-01-30
#
#            latitude  longitude  rel_latitude  rel_longitude
# mls_id
# W8028100  43.673685 -79.449759      0.673685      -0.449759
# W8031028  43.678885 -79.450059      0.678885      -0.450059
# W7390820  43.675711 -79.447539      0.675711      -0.447539

# %%
sorted_comparison[["price", "beds", "dens"]].max()
# Out:
# price    3275000
# beds           4
# dens           2
# dtype: int64

# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline

# %%
# Load data
file = "listings_with_locations.csv"

file_path = Path("../data/" + file)
listings_df = pd.read_csv(file_path, index_col="mls_id", header=0)


listings_df.head()
# Out:
#                                                         url  \
# mls_id
# E8018446  https://toronto.listing.ca/286-main-st-911.E80...
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# W7239426  https://toronto.listing.ca/10-park-lawn-rd-140...
# E8030950  https://toronto.listing.ca/665-queen-st-402.E8...
# E8030860  https://toronto.listing.ca/1190-dundas-st-925....
#
#                        address   price  baths  beds  dens        street  \
# mls_id
# E8018446       286 Main St 911  619900      1     1     1       Main St
# C7266728      215 Queen St 606  529000      1     1     0      Queen St
# W7239426  10 Park Lawn Rd 1408  624900      1     1     1  Park Lawn Rd
# E8030950      665 Queen St 402  899900      2     2     0      Queen St
# E8030860    1190 Dundas St 925  599900      1     1     0     Dundas St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E8018446          East End-Danforth  Toronto  condo_apartment   2024-01-30
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# W7239426                     Mimico  Toronto  condo_apartment   2024-01-30
# E8030950            South Riverdale  Toronto  condo_apartment   2024-01-30
# E8030860            South Riverdale  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude
# mls_id
# E8018446  43.687469 -79.301861
# C7266728  43.650343 -79.387806
# W7239426  43.622946 -79.481658
# E8030950  43.658361 -79.351159
# E8030860  43.665267 -79.341034

# %%
# Remove luxury listings with more than 5 bathrooms or more than 4 beds 
listings_df = listings_df[(listings_df['baths'] != 0) & (listings_df['baths'] <= 5) & (listings_df['beds'] <= 4) & (listings_df['beds'] != 0) & (listings_df['dens'] <= 2)  & (listings_df['price'] <= 2000000)]

# Remove rows with missing latitude values
listings_df = listings_df.dropna(subset=["latitude"])

# %%
# Function to remove outliers (IQR)
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers for each property type

for i in range(4):
    cleaned_df = pd.DataFrame()
    for property_type in listings_df['neighbourhood'].unique():
        subset_df = listings_df[listings_df['neighbourhood'] == property_type]
        cleaned_subset = remove_outliers(subset_df, 'price')
        cleaned_df = pd.concat([cleaned_df, cleaned_subset])
    listings_df = cleaned_df

    cleaned_df = pd.DataFrame()
    for property_type in listings_df['property_type'].unique():
        subset_df = listings_df[listings_df['property_type'] == property_type]
        cleaned_subset = remove_outliers(subset_df, 'price')
        cleaned_df = pd.concat([cleaned_df, cleaned_subset])
    listings_df = cleaned_df

# %%
listings_df = listings_df[listings_df.groupby('neighbourhood').city.transform('count')>10].copy()

# %%
listings_df.count()
# Out:
# url              2862
# address          2862
# price            2862
# baths            2862
# beds             2862
# dens             2862
# street           2862
# neighbourhood    2862
# city             2862
# property_type    2862
# date_scraped     2862
# latitude         2862
# longitude        2862
# dtype: int64

# %%
# Feature engineering
listings_df['rel_latitude'] = listings_df['latitude'] - 43
listings_df['rel_longitude'] = listings_df['longitude'] + 79

listings_df.head()
# Out:
#                                                         url  \
# mls_id
# C7266728  https://toronto.listing.ca/215-queen-st-606.C7...
# C8030612  https://toronto.listing.ca/35-mercer-st-2810.C...
# C8030426  https://toronto.listing.ca/55-mercer-st-710.C8...
# C8030300  https://toronto.listing.ca/35-mercer-st-3711.C...
# C8029936  https://toronto.listing.ca/608-richmond-st-100...
#
#                        address    price  baths  beds  dens       street  \
# mls_id
# C7266728      215 Queen St 606   529000      1     1     0     Queen St
# C8030612     35 Mercer St 2810  1039000      2     2     0    Mercer St
# C8030426      55 Mercer St 710   999000      2     1     1    Mercer St
# C8030300     35 Mercer St 3711  1037000      2     2     0    Mercer St
# C8029936  608 Richmond St 1001   665000      1     1     1  Richmond St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# C7266728  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# C8030612  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# C8030426  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# C8030300  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# C8029936  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude  rel_latitude  rel_longitude
# mls_id
# C7266728  43.650343 -79.387806      0.650343      -0.387806
# C8030612  43.645471 -79.391166      0.645471      -0.391166
# C8030426  43.645397 -79.391362      0.645397      -0.391362
# C8030300  43.645471 -79.391166      0.645471      -0.391166
# C8029936  43.646841 -79.402888      0.646841      -0.402888

# %%
listings_df.nunique()
# Out:
# url              2862
# address          2859
# price             825
# baths               5
# beds                4
# dens                3
# street            699
# neighbourhood      80
# city                1
# property_type       4
# date_scraped        1
# latitude         1402
# longitude        1403
# rel_latitude     1402
# rel_longitude    1403
# dtype: int64

# %%
listings_df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Waterfront Communities C1     327
# Church-Yonge Corridor         187
# Mimico                        149
# Islington-City Centre West    101
# Bay Street Corridor           100
#                              ...
# Edenbridge-Humber Valley       12
# Humewood-Cedarvale             12
# Greenwood-Coxwell              12
# Yonge-Eglinton                 11
# North St. James Town           11
# Name: count, Length: 80, dtype: int64

# %%
# Prepare data for training
cat_columns = ["neighbourhood", "property_type"]
num_columns = ["baths", "beds", "dens", "rel_latitude", "rel_longitude"]
y = listings_df["price"]

# %%
listings_df_prepared = pd.get_dummies(listings_df[cat_columns], dtype=int)
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# C7266728                                           0                        0
# C8030612                                           0                        0
# C8030426                                           0                        0
# C8030300                                           0                        0
# C8029936                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# C7266728                    0                                0
# C8030612                    0                                0
# C8030426                    0                                0
# C8030300                    0                                0
# C8029936                    0                                0
#
#           neighbourhood_Bay Street Corridor  neighbourhood_Bayview Village  \
# mls_id
# C7266728                                  0                              0
# C8030612                                  0                              0
# C8030426                                  0                              0
# C8030300                                  0                              0
# C8029936                                  0                              0
#
#           neighbourhood_Bendale  neighbourhood_Birchcliffe-Cliffside  \
# mls_id
# C7266728                      0                                    0
# C8030612                      0                                    0
# C8030426                      0                                    0
# C8030300                      0                                    0
# C8029936                      0                                    0
#
#           neighbourhood_Black Creek  neighbourhood_Brookhaven-Amesbury  ...  \
# mls_id                                                                  ...
# C7266728                          0                                  0  ...
# C8030612                          0                                  0  ...
# C8030426                          0                                  0  ...
# C8030300                          0                                  0  ...
# C8029936                          0                                  0  ...
#
#           neighbourhood_Willowdale East  neighbourhood_Willowdale West  \
# mls_id
# C7266728                              0                              0
# C8030612                              0                              0
# C8030426                              0                              0
# C8030300                              0                              0
# C8029936                              0                              0
#
#           neighbourhood_Woburn  neighbourhood_Yonge-Eglinton  \
# mls_id
# C7266728                     0                             0
# C8030612                     0                             0
# C8030426                     0                             0
# C8030300                     0                             0
# C8029936                     0                             0
#
#           neighbourhood_York University Heights  \
# mls_id
# C7266728                                      0
# C8030612                                      0
# C8030426                                      0
# C8030300                                      0
# C8029936                                      0
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# C7266728                                 0                              1
# C8030612                                 0                              1
# C8030426                                 0                              1
# C8030300                                 0                              1
# C8029936                                 0                              1
#
#           property_type_condo_townhome  property_type_detached_home  \
# mls_id
# C7266728                             0                            0
# C8030612                             0                            0
# C8030426                             0                            0
# C8030300                             0                            0
# C8029936                             0                            0
#
#           property_type_freehold _townhome
# mls_id
# C7266728                                 0
# C8030612                                 0
# C8030426                                 0
# C8030300                                 0
# C8029936                                 0
#
# [5 rows x 84 columns]

# %%
listings_df_prepared[num_columns] = listings_df[num_columns]
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# C7266728                                           0                        0
# C8030612                                           0                        0
# C8030426                                           0                        0
# C8030300                                           0                        0
# C8029936                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# C7266728                    0                                0
# C8030612                    0                                0
# C8030426                    0                                0
# C8030300                    0                                0
# C8029936                    0                                0
#
#           neighbourhood_Bay Street Corridor  neighbourhood_Bayview Village  \
# mls_id
# C7266728                                  0                              0
# C8030612                                  0                              0
# C8030426                                  0                              0
# C8030300                                  0                              0
# C8029936                                  0                              0
#
#           neighbourhood_Bendale  neighbourhood_Birchcliffe-Cliffside  \
# mls_id
# C7266728                      0                                    0
# C8030612                      0                                    0
# C8030426                      0                                    0
# C8030300                      0                                    0
# C8029936                      0                                    0
#
#           neighbourhood_Black Creek  neighbourhood_Brookhaven-Amesbury  ...  \
# mls_id                                                                  ...
# C7266728                          0                                  0  ...
# C8030612                          0                                  0  ...
# C8030426                          0                                  0  ...
# C8030300                          0                                  0  ...
# C8029936                          0                                  0  ...
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# C7266728                                 0                              1
# C8030612                                 0                              1
# C8030426                                 0                              1
# C8030300                                 0                              1
# C8029936                                 0                              1
#
#           property_type_condo_townhome  property_type_detached_home  \
# mls_id
# C7266728                             0                            0
# C8030612                             0                            0
# C8030426                             0                            0
# C8030300                             0                            0
# C8029936                             0                            0
#
#           property_type_freehold _townhome  baths  beds  dens  rel_latitude  \
# mls_id
# C7266728                                 0      1     1     0      0.650343
# C8030612                                 0      2     2     0      0.645471
# C8030426                                 0      2     1     1      0.645397
# C8030300                                 0      2     2     0      0.645471
# C8029936                                 0      1     1     1      0.646841
#
#           rel_longitude
# mls_id
# C7266728      -0.387806
# C8030612      -0.391166
# C8030426      -0.391362
# C8030300      -0.391166
# C8029936      -0.402888
#
# [5 rows x 89 columns]

# %%
X = listings_df_prepared
y = listings_df["price"]

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a pipeline with StandardScaler and RandomForestRegressor
rf_pipeline = make_pipeline(StandardScaler(), RandomForestRegressor(n_estimators=500, random_state=1))

# %%
# Train the model and evaluate it using cross-validation
cv_scores = cross_val_score(rf_pipeline, X_train, y_train, cv=5, scoring='neg_mean_absolute_error')

print("Cross-Validation MAE Scores:", -cv_scores)
print("Mean CV MAE:", -cv_scores.mean())
# Out:
# Cross-Validation MAE Scores: [77892.86281319 82105.46965541 74215.74633477 79599.92711099
#  75516.80283487]
# Mean CV MAE: 77866.16174984432

# %%
# Fit the model on the training set
rf_pipeline.fit(X_train, y_train)

# Make predictions on the test set
predictions_test = rf_pipeline.predict(X_test)

# %%
# Evaluate the model on the test set
rf_mae_test = mean_absolute_error(y_test, predictions_test)
print("Random Forest Test MAE:", rf_mae_test)
# Out:
# Random Forest Test MAE: 75975.01441537018

# %%
# Make predictions on the training set
predictions_train = rf_pipeline.predict(X_train)

# %%
test_data = {"Actual": y_test,
        "Predicted": predictions_test}
test_df = pd.DataFrame(test_data)

test_df["ratio"] = abs (test_df["Actual"] - test_df["Predicted"]) / test_df["Actual"]
test_df["Difference"] = abs(test_df["Actual"] - test_df["Predicted"])


train_data = {"Actual": y_train,
        "Predicted": predictions_train}
train_df = pd.DataFrame(train_data)

train_df["ratio"] = abs (train_df["Actual"] - train_df["Predicted"]) / train_df["Actual"]
train_df["Difference"] = abs(train_df["Actual"] - train_df["Predicted"])

comparison_df = pd.concat([test_df, train_df], axis = 0)

og_comparison_df = pd.concat([comparison_df, listings_df], axis = 1)

og_comparison_df.head()
# Out:
#            Actual     Predicted     ratio     Difference  \
# mls_id
# W8018028   625000  5.960324e+05  0.046348   28967.571429
# C7240366  1049000  9.477315e+05  0.096538  101268.530476
# W7254918   589900  5.614356e+05  0.048253   28464.438000
# W7294830  1395000  1.334703e+06  0.043223   60296.562000
# C7358908   619900  6.973219e+05  0.124894   77421.947095
#
#                                                         url  \
# mls_id
# W8018028  https://toronto.listing.ca/2-fieldway-rd-701.W...
# C7240366  https://toronto.listing.ca/15-holmes-ave-504.C...
# W7254918  https://toronto.listing.ca/25-neighbourhood-la...
# W7294830  https://toronto.listing.ca/121-mulock-ave.W729...
# C7358908  https://toronto.listing.ca/330-adelaide-st-703...
#
#                             address    price  baths  beds  dens  \
# mls_id
# W8018028          2 Fieldway Rd 701   625000      1     1     1
# C7240366          15 Holmes Ave 504  1049000      2     3     0
# W7254918  25 Neighbourhood Lane 811   589900      1     1     1
# W7294830             121 Mulock Ave  1395000      4     3     1
# C7358908        330 Adelaide St 703   619900      1     1     1
#
#                       street               neighbourhood     city  \
# mls_id
# W8018028         Fieldway Rd  Islington-City Centre West  Toronto
# C7240366          Holmes Ave             Willowdale East  Toronto
# W7254918  Neighbourhood Lane         Stonegate-Queensway  Toronto
# W7294830          Mulock Ave               Junction Area  Toronto
# C7358908         Adelaide St                   Moss Park  Toronto
#
#                property_type date_scraped   latitude  longitude  rel_latitude  \
# mls_id
# W8018028     condo_apartment   2024-01-30  43.643148 -79.527023      0.643148
# C7240366     condo_apartment   2024-01-30  43.777961 -79.414241      0.777961
# W7254918     condo_apartment   2024-01-30  43.638218 -79.489363      0.638218
# W7294830  freehold _townhome   2024-01-30  43.670984 -79.465552      0.670984
# C7358908     condo_apartment   2024-01-30  43.647552 -79.392448      0.647552
#
#           rel_longitude
# mls_id
# W8018028      -0.527023
# C7240366      -0.414241
# W7254918      -0.489363
# W7294830      -0.465552
# C7358908      -0.392448

# %%
sorted_comparison = og_comparison_df.sort_values(by="ratio", ascending=False)
sorted_comparison.head()
# Out:
#           Actual     Predicted     ratio     Difference  \
# mls_id
# E7387572  699000  1.106244e+06  0.582609  407243.656000
# C7272710  399000  6.197705e+05  0.553310  220770.509293
# E8017516  575000  8.416586e+05  0.463754  266658.631238
# C8029808  548000  7.954429e+05  0.451538  247442.866533
# C7313484  499900  7.194149e+05  0.439118  219514.891981
#
#                                                         url  \
# mls_id
# E7387572  https://toronto.listing.ca/113-mcintosh-st.E73...
# C7272710  https://toronto.listing.ca/14-york-st-409.C727...
# E8017516  https://toronto.listing.ca/485-logan-ave-101.E...
# C8029808  https://toronto.listing.ca/1646-bathurst-st-8....
# C7313484  https://toronto.listing.ca/263-wellington-st-5...
#
#                         address   price  baths  beds  dens         street  \
# mls_id
# E7387572        113 Mcintosh St  699000      1     2     0    Mcintosh St
# C7272710         14 York St 409  399000      1     1     0        York St
# E8017516      485 Logan Ave 101  575000      2     1     0      Logan Ave
# C8029808     1646 Bathurst St 8  548000      1     2     0    Bathurst St
# C7313484  263 Wellington St 505  499900      1     1     1  Wellington St
#
#                       neighbourhood     city    property_type date_scraped  \
# mls_id
# E7387572      Birchcliffe-Cliffside  Toronto    detached_home   2024-01-30
# C7272710  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
# E8017516            South Riverdale  Toronto   condo_townhome   2024-01-30
# C8029808         Humewood-Cedarvale  Toronto  condo_apartment   2024-01-30
# C7313484  Waterfront Communities C1  Toronto  condo_apartment   2024-01-30
#
#            latitude  longitude  rel_latitude  rel_longitude
# mls_id
# E7387572  43.706633 -79.252523      0.706633      -0.252523
# C7272710  43.642037 -79.381615      0.642037      -0.381615
# E8017516  43.666422 -79.344712      0.666422      -0.344712
# C8029808  43.693708 -79.422769      0.693708      -0.422769
# C7313484  43.644702 -79.390959      0.644702      -0.390959

# %%
# Neighbourhood ratios (margin of error)
neigh_comparison = og_comparison_df.groupby("neighbourhood")

neigh_comparison["ratio"].mean().sort_values(ascending=False)
# Out:
# neighbourhood
# O'Connor-Parkview          0.129935
# Weston-Pellam Park         0.126361
# Rouge E11                  0.123152
# Cliffcrest                 0.122571
# Oakwood Village            0.103221
#                              ...
# York University Heights    0.029027
# Bendale                    0.026135
# Kensington-Chinatown       0.025106
# Regent Park                0.020291
# Yonge-Eglinton             0.019773
# Name: ratio, Length: 80, dtype: float64

# %%
sorted_comparison.loc[sorted_comparison["neighbourhood"] == "Corso Italia-Davenport"]
# Out:
# Empty DataFrame
# Columns: [Actual, Predicted, ratio, Difference, url, address, price, baths, beds, dens, street, neighbourhood, city, property_type, date_scraped, latitude, longitude, rel_latitude, rel_longitude]
# Index: []

# %%
sorted_comparison[["price", "beds", "dens"]].max()
# Out:
# price    1999000
# beds           4
# dens           2
# dtype: int64

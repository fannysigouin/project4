# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline

# %%
# Load data
file = "all_listings_2024-02-05.csv"

file_path = Path("../data/sqft/" + file)
price_sqft_df = pd.read_csv(file_path, index_col="mls_id", header=0)


price_sqft_df.head()
# Out:
#                                                         url    price  \
# mls_id
# C7326020  https://torontocondoteam.ca/5106-1-bloor-st-e-...  1699000
# C7362210  https://torontocondoteam.ca/1604-181-huron-st-...   743000
# C7251458  https://torontocondoteam.ca/5109-14-york-st-c7...   698888
# C6792974  https://torontocondoteam.ca/3404-77-harbour-sq...   669900
# C6802076  https://torontocondoteam.ca/906-51-trolley-cre...   575000
#
#                         address  beds  dens  baths       sqft  \
# mls_id
# C7326020    5106 - 1 Bloor St E     2     1      3  1000-1199
# C7362210    1604 - 181 Huron St     1     0      1      0-499
# C7251458      5109 - 14 York St     1     0      1    500-599
# C6792974   3404 - 77 Harbour Sq     1     1      1    600-699
# C6802076  906 - 51 Trolley Cres     1     0      1    500-599
#
#             property_type        street              neighbourhood     city  \
# mls_id
# C7326020  condo_apartment    Bloor St E      Church-Yonge Corridor  Toronto
# C7362210  condo_apartment      Huron St       Kensington-Chinatown  Toronto
# C7251458  condo_apartment       York St  Waterfront Communities C1  Toronto
# C6792974  condo_apartment    Harbour Sq  Waterfront Communities C1  Toronto
# C6802076  condo_apartment  Trolley Cres                  Moss Park  Toronto
#
#          date_scraped
# mls_id
# C7326020   2024-02-05
# C7362210   2024-02-05
# C7251458   2024-02-05
# C6792974   2024-02-05
# C6802076   2024-02-05

# %%
# Extract max sqft
price_sqft_df['sqft'] = price_sqft_df['sqft'].str.extract(r'(\d+)-(\d+)').astype(float).apply(lambda x: np.nanmax(x), axis=1)

# Convert NaN to 0 
price_sqft_df['sqft'] = price_sqft_df['sqft'].fillna(0)

# Convert sqft to integer 
price_sqft_df['sqft'] = price_sqft_df['sqft'].astype(int)

price_sqft_df.head()
# Out:
# /var/folders/pf/9cz24qx15jlb8c5nwxl_hjjh0000gn/T/ipykernel_27201/3454444747.py:2: RuntimeWarning: All-NaN axis encountered
#   price_sqft_df['sqft'] = price_sqft_df['sqft'].str.extract(r'(\d+)-(\d+)').astype(float).apply(lambda x: np.nanmax(x), axis=1)
#                                                         url    price  \
# mls_id
# C7326020  https://torontocondoteam.ca/5106-1-bloor-st-e-...  1699000
# C7362210  https://torontocondoteam.ca/1604-181-huron-st-...   743000
# C7251458  https://torontocondoteam.ca/5109-14-york-st-c7...   698888
# C6792974  https://torontocondoteam.ca/3404-77-harbour-sq...   669900
# C6802076  https://torontocondoteam.ca/906-51-trolley-cre...   575000
#
#                         address  beds  dens  baths  sqft    property_type  \
# mls_id
# C7326020    5106 - 1 Bloor St E     2     1      3  1199  condo_apartment
# C7362210    1604 - 181 Huron St     1     0      1   499  condo_apartment
# C7251458      5109 - 14 York St     1     0      1   599  condo_apartment
# C6792974   3404 - 77 Harbour Sq     1     1      1   699  condo_apartment
# C6802076  906 - 51 Trolley Cres     1     0      1   599  condo_apartment
#
#                 street              neighbourhood     city date_scraped
# mls_id
# C7326020    Bloor St E      Church-Yonge Corridor  Toronto   2024-02-05
# C7362210      Huron St       Kensington-Chinatown  Toronto   2024-02-05
# C7251458       York St  Waterfront Communities C1  Toronto   2024-02-05
# C6792974    Harbour Sq  Waterfront Communities C1  Toronto   2024-02-05
# C6802076  Trolley Cres                  Moss Park  Toronto   2024-02-05

# %%
price_sqft_df.count()
# Out:
# url              2543
# price            2543
# address          2543
# beds             2543
# dens             2543
# baths            2543
# sqft             2543
# property_type    2543
# street           2543
# neighbourhood    2543
# city             2543
# date_scraped     2543
# dtype: int64

# %%
# Create price per sqft
def create_price_per_sqft(listings_df):
    listings_df['price_per_sqft'] = listings_df['price'] / listings_df['sqft']
    listings_df['price_per_sqft'] = listings_df['price_per_sqft'].round(0)
    return listings_df  

listings_df = create_price_per_sqft(price_sqft_df)
listings_df.head()
# Out:
#                                                         url    price  \
# mls_id
# C7326020  https://torontocondoteam.ca/5106-1-bloor-st-e-...  1699000
# C7362210  https://torontocondoteam.ca/1604-181-huron-st-...   743000
# C7251458  https://torontocondoteam.ca/5109-14-york-st-c7...   698888
# C6792974  https://torontocondoteam.ca/3404-77-harbour-sq...   669900
# C6802076  https://torontocondoteam.ca/906-51-trolley-cre...   575000
#
#                         address  beds  dens  baths  sqft    property_type  \
# mls_id
# C7326020    5106 - 1 Bloor St E     2     1      3  1199  condo_apartment
# C7362210    1604 - 181 Huron St     1     0      1   499  condo_apartment
# C7251458      5109 - 14 York St     1     0      1   599  condo_apartment
# C6792974   3404 - 77 Harbour Sq     1     1      1   699  condo_apartment
# C6802076  906 - 51 Trolley Cres     1     0      1   599  condo_apartment
#
#                 street              neighbourhood     city date_scraped  \
# mls_id
# C7326020    Bloor St E      Church-Yonge Corridor  Toronto   2024-02-05
# C7362210      Huron St       Kensington-Chinatown  Toronto   2024-02-05
# C7251458       York St  Waterfront Communities C1  Toronto   2024-02-05
# C6792974    Harbour Sq  Waterfront Communities C1  Toronto   2024-02-05
# C6802076  Trolley Cres                  Moss Park  Toronto   2024-02-05
#
#           price_per_sqft
# mls_id
# C7326020          1417.0
# C7362210          1489.0
# C7251458          1167.0
# C6792974           958.0
# C6802076           960.0

# %%
# Remove luxury listings with more than 5 bathrooms or more than 4 beds 
listings_df = listings_df[(listings_df['baths'] != 0) & (listings_df['baths'] <= 5) & (listings_df['beds'] <= 4) & (listings_df['beds'] != 0) & (listings_df['dens'] <= 2)]

# %%
# Function to remove outliers (IQR)
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers for each property type

for i in range(4):
    cleaned_df = pd.DataFrame()
    for property_type in listings_df['property_type'].unique():
        subset_df = listings_df[listings_df['property_type'] == property_type]
        cleaned_subset = remove_outliers(subset_df, 'price')
        cleaned_df = pd.concat([cleaned_df, cleaned_subset])
    listings_df = cleaned_df

# %%
listings_df.count()
# Out:
# url               1849
# price             1849
# address           1849
# beds              1849
# dens              1849
# baths             1849
# sqft              1849
# property_type     1849
# street            1849
# neighbourhood     1849
# city              1849
# date_scraped      1849
# price_per_sqft    1849
# dtype: int64

# %%
listings_df['neighbourhood'].value_counts()
# Out:
# Waterfront Communities C1        187
# Church-Yonge Corridor             93
# Mimico                            84
# Willowdale East                   67
# Niagara                           61
#                                 ...
# Trinity-Bellwoods                  1
# Blake-Jones                        1
# Thistletown-Beaumonde Heights      1
# Danforth                           1
# Rustic                             1
# Name: neighbourhood, Length: 134, dtype: int64

# %%
# Prepare data for training
cat_columns = ["neighbourhood", "property_type"]
num_columns = ["baths", "beds", "dens", "price_per_sqft", "sqft"]
y = listings_df["price"]

# %%
listings_df_prepared = pd.get_dummies(listings_df[cat_columns], dtype=int)
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt North  \
# mls_id
# C7362210                              0
# C7251458                              0
# C6792974                              0
# C6802076                              0
# W7358808                              0
#
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# C7362210                                           0                        0
# C7251458                                           0                        0
# C6792974                                           0                        0
# C6802076                                           0                        0
# W7358808                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# C7362210                    0                                0
# C7251458                    0                                0
# C6792974                    0                                0
# C6802076                    0                                0
# W7358808                    0                                0
#
#           neighbourhood_Bathurst Manor  neighbourhood_Bay Street Corridor  \
# mls_id
# C7362210                             0                                  0
# C7251458                             0                                  0
# C6792974                             0                                  0
# C6802076                             0                                  0
# W7358808                             0                                  0
#
#           neighbourhood_Bayview Village  neighbourhood_Bayview Woods-Steeles  \
# mls_id
# C7362210                              0                                    0
# C7251458                              0                                    0
# C6792974                              0                                    0
# C6802076                              0                                    0
# W7358808                              0                                    0
#
#           neighbourhood_Bedford Park-Nortown  ...  \
# mls_id                                        ...
# C7362210                                   0  ...
# C7251458                                   0  ...
# C6792974                                   0  ...
# C6802076                                   0  ...
# W7358808                                   0  ...
#
#           neighbourhood_Willowridge-Martingrove-Richview  \
# mls_id
# C7362210                                               0
# C7251458                                               0
# C6792974                                               0
# C6802076                                               0
# W7358808                                               0
#
#           neighbourhood_Woburn  neighbourhood_Woodbine Corridor  \
# mls_id
# C7362210                     0                                0
# C7251458                     0                                0
# C6792974                     0                                0
# C6802076                     0                                0
# W7358808                     0                                0
#
#           neighbourhood_Woodbine-Lumsden  neighbourhood_Wychwood  \
# mls_id
# C7362210                               0                       0
# C7251458                               0                       0
# C6792974                               0                       0
# C6802076                               0                       0
# W7358808                               0                       0
#
#           neighbourhood_Yonge-Eglinton  neighbourhood_Yonge-St. Clair  \
# mls_id
# C7362210                             0                              0
# C7251458                             0                              0
# C6792974                             0                              0
# C6802076                             0                              0
# W7358808                             0                              0
#
#           neighbourhood_York University Heights  \
# mls_id
# C7362210                                      0
# C7251458                                      0
# C6792974                                      0
# C6802076                                      0
# W7358808                                      0
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment
# mls_id
# C7362210                                 0                              1
# C7251458                                 0                              1
# C6792974                                 0                              1
# C6802076                                 0                              1
# W7358808                                 0                              1
#
# [5 rows x 135 columns]

# %%
listings_df_prepared[num_columns] = listings_df[num_columns]
listings_df_prepared.head()
# Out:
#           neighbourhood_Agincourt North  \
# mls_id
# C7362210                              0
# C7251458                              0
# C6792974                              0
# C6802076                              0
# W7358808                              0
#
#           neighbourhood_Agincourt South-Malvern West  neighbourhood_Alderwood  \
# mls_id
# C7362210                                           0                        0
# C7251458                                           0                        0
# C6792974                                           0                        0
# C6802076                                           0                        0
# W7358808                                           0                        0
#
#           neighbourhood_Annex  neighbourhood_Banbury-Don Mills  \
# mls_id
# C7362210                    0                                0
# C7251458                    0                                0
# C6792974                    0                                0
# C6802076                    0                                0
# W7358808                    0                                0
#
#           neighbourhood_Bathurst Manor  neighbourhood_Bay Street Corridor  \
# mls_id
# C7362210                             0                                  0
# C7251458                             0                                  0
# C6792974                             0                                  0
# C6802076                             0                                  0
# W7358808                             0                                  0
#
#           neighbourhood_Bayview Village  neighbourhood_Bayview Woods-Steeles  \
# mls_id
# C7362210                              0                                    0
# C7251458                              0                                    0
# C6792974                              0                                    0
# C6802076                              0                                    0
# W7358808                              0                                    0
#
#           neighbourhood_Bedford Park-Nortown  ...  \
# mls_id                                        ...
# C7362210                                   0  ...
# C7251458                                   0  ...
# C6792974                                   0  ...
# C6802076                                   0  ...
# W7358808                                   0  ...
#
#           neighbourhood_Yonge-Eglinton  neighbourhood_Yonge-St. Clair  \
# mls_id
# C7362210                             0                              0
# C7251458                             0                              0
# C6792974                             0                              0
# C6802076                             0                              0
# W7358808                             0                              0
#
#           neighbourhood_York University Heights  \
# mls_id
# C7362210                                      0
# C7251458                                      0
# C6792974                                      0
# C6802076                                      0
# W7358808                                      0
#
#           neighbourhood_Yorkdale-Glen Park  property_type_condo_apartment  \
# mls_id
# C7362210                                 0                              1
# C7251458                                 0                              1
# C6792974                                 0                              1
# C6802076                                 0                              1
# W7358808                                 0                              1
#
#           baths  beds  dens  price_per_sqft  sqft
# mls_id
# C7362210      1     1     0          1489.0   499
# C7251458      1     1     0          1167.0   599
# C6792974      1     1     1           958.0   699
# C6802076      1     1     0           960.0   599
# W7358808      2     2     0           876.0   799
#
# [5 rows x 140 columns]

# %%
X = listings_df_prepared
y = listings_df["price"]

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Remove infinite values
X_train = X_train.replace([np.inf, -np.inf], np.nan)
X_train = X_train.dropna()

# Remove corresponding rows from y_train
y_train = y_train.loc[X_train.index]

# %%
# Create a pipeline with StandardScaler and RandomForestRegressor
rf_pipeline = make_pipeline(StandardScaler(), RandomForestRegressor(n_estimators=500, random_state=1))

# %%
# Scale features 
X_train_scaled = StandardScaler().fit_transform(X_train)

# %%
# Train the model and evaluate it using cross-validation
cv_scores = cross_val_score(rf_pipeline, X_train_scaled, y_train, cv=5, scoring='neg_mean_absolute_error')

print("Cross-Validation MAE Scores:", -cv_scores)
print("Mean CV MAE:", -cv_scores.mean())
# Out:
# Cross-Validation MAE Scores: [ 7929.42226532 10913.05833099 13674.74699652 13829.57580855
#  13675.36264067]
# Mean CV MAE: 12004.433208410284

# %%
# Remove infinite values from X_test
X_test = X_test.replace([np.inf, -np.inf], np.nan)
X_test = X_test.dropna()

# Remove corresponding rows from y_test
y_test = y_test.loc[X_test.index]

# %%
# Fit the StandardScaler on the training data
rf_pipeline.fit(X_train, y_train)

# Scale features for the test set using the fitted StandardScaler
X_test_scaled = rf_pipeline.named_steps['standardscaler'].transform(X_test)

# Now, you can make predictions on the scaled test set
predictions_test = rf_pipeline.predict(X_test_scaled)
# Out:
# /Users/nardyjh/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Evaluate the model on the test set
rf_mae_test = mean_absolute_error(y_test, predictions_test)
print("Random Forest Test MAE:", rf_mae_test)
# Out:
# Random Forest Test MAE: 460484.6829831326

# %%
# Make predictions on the training set
predictions_train = rf_pipeline.predict(X_train)

# %%
test_data = {"Actual": y_test,
        "Predicted": predictions_test}
test_df = pd.DataFrame(test_data)

test_df["ratio"] = abs (test_df["Actual"] - test_df["Predicted"]) / test_df["Actual"]
test_df["Difference"] = abs(test_df["Actual"] - test_df["Predicted"])


train_data = {"Actual": y_train,
        "Predicted": predictions_train}
train_df = pd.DataFrame(train_data)

train_df["ratio"] = abs (train_df["Actual"] - train_df["Predicted"]) / train_df["Actual"]
train_df["Difference"] = abs(train_df["Actual"] - train_df["Predicted"])

comparison_df = pd.concat([test_df, train_df], axis = 0)

og_comparison_df = pd.concat([comparison_df, listings_df], axis = 1)

og_comparison_df.head()
# Out:
#             Actual  Predicted     ratio  Difference  \
# mls_id
# C7018306  768000.0   270057.6  0.648363    497942.4
# C7362182  938000.0   269937.4  0.712220    668062.6
# C7002864  649900.0   269937.4  0.584648    379962.6
# W7034258  949000.0   269937.4  0.715556    679062.6
# C7233376  728000.0   270460.4  0.628488    457539.6
#
#                                                         url   price  \
# mls_id
# C7018306  https://torontocondoteam.ca/3201-426-universit...  768000
# C7362182  https://torontocondoteam.ca/1804-83-redpath-av...  938000
# C7002864  https://torontocondoteam.ca/lph06-16-harrison-...  649900
# W7034258  https://torontocondoteam.ca/2110-1-aberfoyle-c...  949000
# C7233376  https://torontocondoteam.ca/4205-85-queens-wha...  728000
#
#                                   address  beds  dens  baths  sqft  \
# mls_id
# C7018306        3201 - 426 University Ave     1     1      1   799
# C7362182            1804 - 83 Redpath Ave     2     0      2   999
# C7002864  Lph06 - 16 Harrison Garden Blvd     1     0      1   599
# W7034258          2110 - 1 Aberfoyle Cres     2     0      2  1399
# C7233376        4205 - 85 Queens Wharf Rd     1     1      1   699
#
#             property_type                           street  \
# mls_id
# C7018306  condo_apartment                   University Ave
# C7362182  condo_apartment                      Redpath Ave
# C7002864  condo_apartment  Lph06 - 16 Harrison Garden Blvd
# W7034258  condo_apartment                   Aberfoyle Cres
# C7233376  condo_apartment                  Queens Wharf Rd
#
#                        neighbourhood     city date_scraped  price_per_sqft
# mls_id
# C7018306                  University  Toronto   2024-02-05           961.0
# C7362182         Mount Pleasant West  Toronto   2024-02-05           939.0
# C7002864             Willowdale East  Toronto   2024-02-05          1085.0
# W7034258  Islington-City Centre West  Toronto   2024-02-05           678.0
# C7233376   Waterfront Communities C1  Toronto   2024-02-05          1041.0

# %%
sorted_comparison = og_comparison_df.sort_values(by="ratio", ascending=False)
sorted_comparison.head()
# Out:
#              Actual   Predicted     ratio   Difference  \
# mls_id
# E7386944  1299000.0  269937.400  0.792196  1029062.600
# E7211614  1299000.0  269937.400  0.792196  1029062.600
# C7389668  1249900.0  269937.400  0.784033   979962.600
# W7214952  1249999.0  270057.600  0.783954   979941.400
# C6787140  1289000.0  281405.398  0.781687  1007594.602
#
#                                                         url    price  \
# mls_id
# E7386944  https://torontocondoteam.ca/301-35-boardwalk-d...  1299000
# E7211614  https://torontocondoteam.ca/104-14-dewhurst-bl...  1299000
# C7389668  https://torontocondoteam.ca/707-200-sudbury-st...  1249900
# W7214952  https://torontocondoteam.ca/2507-2121-lake-sho...  1249999
# C6787140  https://torontocondoteam.ca/303-188-spadina-av...  1289000
#
#                                 address  beds  dens  baths  sqft  \
# mls_id
# E7386944          301 - 35 Boardwalk Dr     2     0      2  1399
# E7211614         104 - 14 Dewhurst Blvd     2     0      2  1199
# C7389668           707 - 200 Sudbury St     2     0      2   899
# W7214952  2507 - 2121 Lake Shore Blvd W     2     1      2  1199
# C6787140          303 - 188 Spadina Ave     3     0      2  1799
#
#             property_type             street         neighbourhood     city  \
# mls_id
# E7386944  condo_apartment       Boardwalk Dr           The Beaches  Toronto
# E7211614  condo_apartment      Dewhurst Blvd              Danforth  Toronto
# C7389668  condo_apartment         Sudbury St       Little Portugal  Toronto
# W7214952  condo_apartment  Lake Shore Blvd W                Mimico  Toronto
# C6787140  condo_apartment        Spadina Ave  Kensington-Chinatown  Toronto
#
#          date_scraped  price_per_sqft
# mls_id
# E7386944   2024-02-05           929.0
# E7211614   2024-02-05          1083.0
# C7389668   2024-02-05          1390.0
# W7214952   2024-02-05          1043.0
# C6787140   2024-02-05           717.0

# %%
# Neighbourhood ratios (margin of error)
neigh_comparison = og_comparison_df.groupby("neighbourhood")

neigh_comparison["ratio"].mean().sort_values(ascending=False)
# Out:
# neighbourhood
# Danforth                         0.792196
# Humberlea-Pelmo Park W4          0.741192
# Humber Summit                    0.550029
# Guildwood                        0.535620
# Trinity-Bellwoods                0.532980
#                                    ...
# Lambton Baby Point                    NaN
# Lawrence Park South                   NaN
# Oakridge                              NaN
# Runnymede-Bloor West Village          NaN
# Thistletown-Beaumonde Heights         NaN
# Name: ratio, Length: 134, dtype: float64

# %%
sorted_comparison.loc[sorted_comparison["neighbourhood"] == "Danforth"]
# Out:
#              Actual  Predicted     ratio  Difference  \
# mls_id
# E7211614  1299000.0   269937.4  0.792196   1029062.6
#
#                                                         url    price  \
# mls_id
# E7211614  https://torontocondoteam.ca/104-14-dewhurst-bl...  1299000
#
#                          address  beds  dens  baths  sqft    property_type  \
# mls_id
# E7211614  104 - 14 Dewhurst Blvd     2     0      2  1199  condo_apartment
#
#                  street neighbourhood     city date_scraped  price_per_sqft
# mls_id
# E7211614  Dewhurst Blvd      Danforth  Toronto   2024-02-05          1083.0

# %%
sorted_comparison[["price", "beds", "dens"]].max()
# Out:
# price    1300000
# beds           4
# dens           2
# dtype: int64
